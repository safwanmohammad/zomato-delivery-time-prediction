# %% [markdown]
# <h1 style="text-align: center; color: Seagreen; text-transform: uppercase;">
#    Zomato delivery time prediction
# </h1>

# %% [markdown]
# <h2 style="text-align: start; color: SteelBlue; text-transform: uppercase;">
#    Technical Approach
# </h2>

# %% [raw]
# 1. Problem Understanding
#
# 2. Data Collection
#
# 3. Data Cleaning
#
# 4. Feature Engineering
#
# 5. Exploratory Data Analysis (EDA)
#
# 6. Train-Test Split
#
# 7. Missing Value Handling
#
# 8. Outlier Handling
#
# 9. Encoding
#
# 10. Scaling
#
# 11. Model Building
#
# 12. Model Evaluation
#
# 13. Hyperparameter Tuning
#
# 14. Feature Importance / Model Interpretation
#
# 15. Final Insights & Business Conclusion
#
# 16. Deployment

# %% [markdown]
# <h2 style="text-align: start; color: SteelBlue; text-transform: uppercase;">
#    Problem Understanding
# </h2

# %% [markdown]
# <h3 style="text-align: start; color:red; text-transform: uppercase;">
#     Business Problem
# </h3>

# %% [raw]
# Food delivery companies often face challenges such as delayed deliveries, customer dissatisfaction, and inefficient delivery operations. Predicting delivery time accurately is important to improve operational efficiency and provide better customer service.

# %% [markdown]
# <h3 style="text-align: start; color:red; text-transform: uppercase;">
#     Project Objective
# </h3>

# %% [raw]
# The main objective of this project is to build a machine learning model that can accurately predict food delivery time based on factors such as traffic conditions, weather, delivery location, vehicle type, and delivery personnel information.

# %% [markdown]
# <h3 style="text-align: start; color:red; text-transform: uppercase;">
#    Importance of Delivery Time Prediction
# </h3>

# %% [raw]
# Accurate delivery time prediction helps customers receive reliable estimated delivery times (ETA), improves customer satisfaction, reduces delays, and supports better delivery management for food delivery companies.

# %% [markdown]
# <h3 style="text-align: start; color:red; text-transform: uppercase;">
#     Machine Learning Problem Type
# </h3>

# %% [raw]
# Since the target variable `Time_taken (min)` is a continuous numerical value, this project is formulated as a supervised machine learning regression problem.

# %% [markdown]
# <h3 style="text-align: start; color:red; text-transform: uppercase;">
#     Target Variable
# </h3>

# %% [raw]
# The target variable used in this project is `Time_taken (min)`, which represents the total time taken to complete a food delivery in minutes.

# %% [markdown]
# <h3 style="text-align: start; color:red; text-transform: uppercase;">
#     Input Features
# </h3>

# %% [raw]
# The dataset contains several input features related to delivery operations, including delivery personnel details, restaurant and delivery location coordinates, weather conditions, road traffic density, vehicle information, order timing details, festival indicators, and city information. These features may influence the total delivery duration and help in predicting delivery time more accurately.

# %% [markdown]
# <h3 style="text-align: start; color:red; text-transform: uppercase;">
#    Business Impact
# </h3>

# %% [raw]
# Accurate prediction of delivery time can help food delivery companies improve operational efficiency, optimize delivery management, reduce delays, and enhance customer satisfaction. It also helps businesses allocate delivery resources more effectively and improve overall service quality.

# %% [markdown]
# <h2 style="text-align: start; color: SteelBlue; text-transform: uppercase;">
#    Feature Descriptions
# </h2>

# %% [raw]
# 1.ID: Unique identifier for each delivery.
#
# 2.Delivery_person_ID: Unique identifier for each delivery person.
#
# 3.Delivery_person_Age: Age of the delivery person.
#
# 4.Delivery_person_Ratings: Ratings assigned to the delivery person.
#
# 5.Restaurant_latitude: Latitude of the restaurant.
#
# 6.Restaurant_longitude: Longitude of the restaurant.
#
# 7.Delivery_location_latitude: Latitude of the delivery location.
#
# 8.Delivery_location_longitude: Longitude of the delivery location.
#
# 9.Order_Date: Date of the order.
#
# 10.Time_Ordered: Time the order was placed.
#
# 11.Time_Order_picked: Time the order was picked up for delivery.
#
# 12.Weather_conditions: Weather conditions at the time of delivery.
#
# 13.Road_traffic_density: Density of road traffic during delivery.
#
# 14.Vehicle_condition: Condition of the delivery vehicle.
#     0 = poor
#     1 = average
#     2 = good
#
# 15.Type_of_order: Type of order (e.g., dine-in, takeaway, delivery).
#
# 16.Type_of_vehicle: Type of vehicle used for delivery.
#
# 17.Multiple_deliveries: Indicator of whether multiple deliveries were made in the same trip.
#     0 → single delivery
#     1 → one additional delivery
#     2 → multiple stacked deliveries
#     3 → very rare high-load deliveries
#
# 18.Festival: Indicator of whether the delivery coincided with a festival.
#
# 19.City: City where the delivery took place.
#
# 20.Time_taken (min): Time taken for delivery in minutes.

# %% [markdown]
# <h2 style="text-align: start; color: SteelBlue; text-transform: uppercase;">
#    Data collection
# </h2>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
sns.set_style("darkgrid")
import warnings
import reverse_geocoder as rg
warnings.filterwarnings('ignore')
warnings.warn('this will not show')

# %%
data = pd.read_csv(r"C:\Users\babus\Data_Spark\Machine Learning\Data_collections\Project\Zomato Dataset.csv")

# %%
data.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# 0                    78.116106  12-02-2022       21:55             22:10
# 1                    76.347589  13-02-2022       14:55             15:05
# 2                    74.006619  04-03-2022       17:30             17:40
# 3                    75.829346  13-02-2022       09:20             09:30
# 4                    80.502929  14-02-2022       19:50             20:05
#
#   Weather_conditions Road_traffic_density  Vehicle_condition Type_of_order  \
# 0                Fog                  Jam                  2         Snack
# 1             Stormy                 High                  1          Meal
# 2         Sandstorms               Medium                  1        Drinks
# 3         Sandstorms                  Low                  0        Buffet
# 4                Fog                  Jam                  1         Snack
#
#   Type_of_vehicle  multiple_deliveries Festival           City  \
# 0      motorcycle                  3.0       No  Metropolitian
# 1      motorcycle                  1.0       No  Metropolitian
# 2         scooter                  1.0       No  Metropolitian
# 3      motorcycle                  0.0       No  Metropolitian
# 4         scooter                  1.0       No  Metropolitian
#
#    Time_taken (min)
# 0                46
# 1                23
# 2                21
# 3                20
# 4                41

# %%
data.tail()
# Out:
#            ID Delivery_person_ID  Delivery_person_Age  \
# 45579  0x7c09      JAPRES04DEL01                 30.0
# 45580  0xd641      AGRRES16DEL01                 21.0
# 45581  0x4f8d     CHENRES08DEL03                 30.0
# 45582  0x5eee    COIMBRES11DEL01                 20.0
# 45583  0x5fb2   RANCHIRES09DEL02                 23.0
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 45579                      4.8            26.902328             75.794257
# 45580                      4.6             0.000000              0.000000
# 45581                      4.9            13.022394             80.242439
# 45582                      4.7            11.001753             76.986241
# 45583                      4.9            23.351058             85.325731
#
#        Delivery_location_latitude  Delivery_location_longitude  Order_Date  \
# 45579                   26.912328                    75.804257  24-03-2022
# 45580                    0.070000                     0.070000  16-02-2022
# 45581                   13.052394                    80.272439  11-03-2022
# 45582                   11.041753                    77.026241  07-03-2022
# 45583                   23.431058                    85.405731  02-03-2022
#
#       Time_Orderd Time_Order_picked Weather_conditions Road_traffic_density  \
# 45579       11:35             11:45              Windy                 High
# 45580       19:55             20:10              Windy                  Jam
# 45581       23:50          24:05:00             Cloudy                  Low
# 45582       13:35             13:40             Cloudy                 High
# 45583       17:10             17:15                Fog               Medium
#
#        Vehicle_condition Type_of_order Type_of_vehicle  multiple_deliveries  \
# 45579                  1          Meal      motorcycle                  0.0
# 45580                  0        Buffet      motorcycle                  1.0
# 45581                  1        Drinks         scooter                  0.0
# 45582                  0         Snack      motorcycle                  1.0
# 45583                  2         Snack         scooter                  1.0
#
#       Festival           City  Time_taken (min)
# 45579       No  Metropolitian                32
# 45580       No  Metropolitian                36
# 45581       No  Metropolitian                16
# 45582       No  Metropolitian                26
# 45583       No  Metropolitian                36

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45584 entries, 0 to 45583
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           45584 non-null  object
#  1   Delivery_person_ID           45584 non-null  object
#  2   Delivery_person_Age          43730 non-null  float64
#  3   Delivery_person_Ratings      43676 non-null  float64
#  4   Restaurant_latitude          45584 non-null  float64
#  5   Restaurant_longitude         45584 non-null  float64
#  6   Delivery_location_latitude   45584 non-null  float64
#  7   Delivery_location_longitude  45584 non-null  float64
#  8   Order_Date                   45584 non-null  object
#  9   Time_Orderd                  43853 non-null  object
#  10  Time_Order_picked            45584 non-null  object
#  11  Weather_conditions           44968 non-null  object
#  12  Road_traffic_density         44983 non-null  object
#  13  Vehicle_condition            45584 non-null  int64
#  14  Type_of_order                45584 non-null  object
#  15  Type_of_vehicle              45584 non-null  object
#  16  multiple_deliveries          44591 non-null  float64
#  17  Festival                     45356 non-null  object
#  18  City                         44384 non-null  object
#  19  Time_taken (min)             45584 non-null  int64
# dtypes: float64(7), int64(2), object(11)
# memory usage: 7.0+ MB

# %%
data.shape
# Out:
# (45584, 20)

# %%
data.columns
# Out:
# Index(['ID', 'Delivery_person_ID', 'Delivery_person_Age',
#        'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Order_Date', 'Time_Orderd',
#        'Time_Order_picked', 'Weather_conditions', 'Road_traffic_density',
#        'Vehicle_condition', 'Type_of_order', 'Type_of_vehicle',
#        'multiple_deliveries', 'Festival', 'City', 'Time_taken (min)'],
#       dtype='object')

# %%
num_columns = data.select_dtypes(exclude='object').columns
num_columns
# Out:
# Index(['Delivery_person_Age', 'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Vehicle_condition',
#        'multiple_deliveries', 'Time_taken (min)'],
#       dtype='object')

# %%
obj_columns = data.select_dtypes(include='object').columns
obj_columns
# Out:
# Index(['ID', 'Delivery_person_ID', 'Order_Date', 'Time_Orderd',
#        'Time_Order_picked', 'Weather_conditions', 'Road_traffic_density',
#        'Type_of_order', 'Type_of_vehicle', 'Festival', 'City'],
#       dtype='object')

# %% [markdown]
# <h2 style="text-align: start; color: SteelBlue; text-transform: uppercase;">
#    Data Cleaning
# </h2>

# %%
data.isna().sum()
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age            1854
# Delivery_person_Ratings        1908
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weather_conditions              616
# Road_traffic_density            601
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             993
# Festival                        228
# City                           1200
# Time_taken (min)                  0
# dtype: int64

# %% [markdown]
# ### Checking Duplicate

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Checking Data Types

# %%
for col in data:
    print(f"----------{col}-----------")
    
    print(data[col].unique(),'\n')
# Out:
# ----------ID-----------
# ['0xcdcd' '0xd987' '0x2784' ... '0x4f8d' '0x5eee' '0x5fb2']
#
# ----------Delivery_person_ID-----------
# ['DEHRES17DEL01' 'KOCRES16DEL01' 'PUNERES13DEL03' ... 'KOCRES04DEL01'
#  'BHPRES06DEL03' 'GOARES03DEL03']
#
# ----------Delivery_person_Age-----------
# [36. 21. 23. 34. 24. 29. 35. 33. 25. 31. 37. 27. 32. 26. 38. 20. 22. nan
#  28. 39. 30. 15. 50.]
#
# ----------Delivery_person_Ratings-----------
# [4.2 4.7 4.3 4.5 4.  4.9 4.1 5.  4.8 3.5 4.6 nan 4.4 3.8 3.9 3.7 2.6 2.5
#  3.6 3.1 2.7 1.  3.2 3.3 6.  3.4 2.8 2.9 3. ]
#
# ----------Restaurant_latitude-----------
# [ 30.327968  10.003064  18.56245   30.899584  26.463504  19.176269
#   12.311072  18.592718  17.426228  22.552672  18.563934  23.357804
#   11.003669  12.986047  19.221315  13.005801  26.849596  21.160522
#   12.934179  18.51421   11.022477  21.160437  15.51315   15.561295
#    0.        18.55144   18.593481  21.173343  17.451976  12.972532
#   13.064181  19.121999  21.149569  19.091458  22.539129  12.970324
#   21.175975  23.369746  12.914264  11.003681  10.96185   27.165108
#   26.88842   26.913987  12.3085    21.183434  19.254567  25.449659
#   30.372202  12.972793  21.157735  21.186438  12.935662  17.431477
#   12.933298  22.311358  12.934365  13.086438  26.913483  17.411028
#   18.516216  15.5696    19.876428  12.939496  17.433809  23.374878
#  -27.163303  22.74806   26.891191  12.316967  18.927584  11.022298
#   12.325461  18.530963  17.458998  19.1813    22.727021  12.979166
#   18.994237  12.284747  11.000762  26.479108  21.175104  12.975377
#   23.359194  12.297954  23.359407  23.416792  26.892312  22.31279
#   22.761593  11.026117  26.483042  23.359033  22.569358  21.157729
#   22.311603  18.536562  22.745536  18.543626  17.41233   21.17106
#
# ----------Time_Order_picked-----------
# ['22:10' '15:05' '17:40' '09:30' '20:05' '20:35' '15:10' '20:40' '20:50'
#  '21:30' '20:25' '22:45' '08:30' '19:45' '12:30' '18:50' '23:30' '21:35'
#  '23:45' '22:50' '22:40' '23:35' '13:40' '21:45' '19:10' '14:25' '11:10'
#  '09:55' '08:55' '23:10' '17:30' '18:35' '19:50' '19:25' '0.458333333'
#  '19:15' '16:55' '11:40' '15:15' '22:55' '22:25' '20:55' '23:05' '0.75'
#  '0.958333333' '09:40' '20:20' '22:35' '0.916666667' '23:55' '15:40'
#  '10:30' '0.875' '10:50' '16:05' '20:15' '12:15' '15:45' '22:15' '10:45'
#  '15:30' '24:05:00' '21:25' '12:45' '21:15' '18:20' '18:25' '11:50'
#  '12:50' '10:55' '21:40' '10:20' '17:55' '23:50' '12:55' '24:10:00'
#  '10:40' '0.375' '20:45' '0.833333333' '23:15' '22:20' '21:05'
#  '0.708333333' '24:15:00' '21:20' '14:35' '10:25' '09:05' '16:50' '08:40'
#  '23:40' '21:50' '19:55' '0.625' '10:35' '09:25' '17:20' '19:30' '17:25'
#  '20:10' '1' '17:35' '0.791666667' '19:05' '13:20' '17:50' '18:05' '19:20'
#  '10:05' '09:10' '21:55' '19:40' '18:10' '09:50' '15:50' '18:30' '18:15'
#  '16:15' '11:15' '21:10' '22:30' '15:20' '18:40' '23:20' '11:25' '13:55'
#  '18:45' '22:05' '11:55' '18:55' '09:45' '17:15' '12:05' '0.5' '19:35'
#  '08:25' '11:05' '15:35' '12:40' '12:25' '08:20' '23:25' '16:10' '13:45'
#  '08:15' '08:45' '20:30' '0.541666667' '11:20' '08:50' '14:45' '17:45'
#  '0.416666667' '08:35' '12:10' '11:35' '14:30' '10:15' '17:05' '10:10'
#  '09:35' '11:30' '16:25' '09:15' '13:35' '15:55' '13:10' '13:05' '11:45'
#  '16:20' '16:30' '16:45' '09:20' '13:25' '14:15' '14:05' '16:35' '16:40'
#  '13:30' '14:40' '12:20' '13:50' '17:10' '15:25' '14:20' '12:35'
#  '0.583333333' '14:10' '14:55' '13:15' '14:50' '0.666666667']
#
# ----------Weather_conditions-----------
# ['Fog' 'Stormy' 'Sandstorms' 'Windy' 'Cloudy' 'Sunny' nan]
#
# ----------Road_traffic_density-----------
# ['Jam' 'High' 'Medium' 'Low' nan]
#
# ----------Vehicle_condition-----------
# [2 1 0 3]
#
# ----------Type_of_order-----------
# ['Snack' 'Meal' 'Drinks' 'Buffet']
#
# ----------Type_of_vehicle-----------
# ['motorcycle' 'scooter' 'electric_scooter' 'bicycle']
#
# ----------multiple_deliveries-----------
# [ 3.  1.  0. nan  2.]
#
# ----------Festival-----------
# ['No' 'Yes' nan]
#
# ----------City-----------
# ['Metropolitian' 'Urban' 'Semi-Urban' nan]
#
# ----------Time_taken (min)-----------
# [46 23 21 20 41 33 40 15 36 26 39 34 18 38 47 12 22 25 35 30 10 19 11 28
#  52 16 27 49 24 17 14 37 44 42 31 13 29 50 43 48 32 54 53 45 51]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45584 entries, 0 to 45583
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           45584 non-null  object
#  1   Delivery_person_ID           45584 non-null  object
#  2   Delivery_person_Age          43730 non-null  float64
#  3   Delivery_person_Ratings      43676 non-null  float64
#  4   Restaurant_latitude          45584 non-null  float64
#  5   Restaurant_longitude         45584 non-null  float64
#  6   Delivery_location_latitude   45584 non-null  float64
#  7   Delivery_location_longitude  45584 non-null  float64
#  8   Order_Date                   45584 non-null  object
#  9   Time_Orderd                  43853 non-null  object
#  10  Time_Order_picked            45584 non-null  object
#  11  Weather_conditions           44968 non-null  object
#  12  Road_traffic_density         44983 non-null  object
#  13  Vehicle_condition            45584 non-null  int64
#  14  Type_of_order                45584 non-null  object
#  15  Type_of_vehicle              45584 non-null  object
#  16  multiple_deliveries          44591 non-null  float64
#  17  Festival                     45356 non-null  object
#  18  City                         44384 non-null  object
#  19  Time_taken (min)             45584 non-null  int64
# dtypes: float64(7), int64(2), object(11)
# memory usage: 7.0+ MB

# %% [raw]
# The dataset contained several data quality issues such as incorrect data types, inconsistent formatting, invalid values, and corrupted entries. Proper preprocessing was performed before analysis and model building to improve data quality and reliability.
#
# The `Order_Date` column was stored as object datatype and was converted into datetime format for date-based analysis.
#
# The `Time_Orderd` and `Time_Order_picked` columns contained inconsistent time formats, invalid entries, and corrupted values such as decimal-style time representations and invalid timestamps like `24:05:00`.
# These columns were cleaned and standardized before converting them into proper time format.
#
# The columns `Delivery_person_Age`, `Delivery_person_Ratings`, and `multiple_deliveries` were converted into numeric datatype for numerical analysis and modeling.
# During validation, unrealistic values such as ratings greater than the expected range were identified and cleaned appropriately.
#
# The geographical coordinate columns including `Restaurant_latitude`, `Restaurant_longitude`, `Delivery_location_latitude`, and `Delivery_location_longitude` were validated to identify incorrect coordinate values, zero values, and inconsistent sign issues.
#
# Categorical columns such as `Weather_conditions`, `Road_traffic_density`, `Festival`, and `City` were checked for inconsistent formatting and typographical errors.
# Category labels were standardized to maintain consistency across the dataset. For example, incorrect category names such as `Metropolitian` were corrected during preprocessing.

# %% [markdown]
# <h3 style="text-align: start; color: wheat;">
#    Order_Date
# </h3>

# %%
data['Order_Date'] = pd.to_datetime( data['Order_Date'] ,dayfirst=True )

# %% [markdown]
# <h3 style="text-align: start; color: wheat;">
#    Time_Orderd
# </h3>

# %%
in_correct_time = data[~data['Time_Orderd'].astype(str).str.contains(':', na=False)]

in_correct_time['Time_Orderd'].unique()
# Out:
# array(['0.458333333', '0.958333333', nan, '0.791666667', '0.875', '1',
#        '0.375', '0.625', '0.833333333', '0.666666667', '0.75',
#        '0.416666667', '0.916666667', '0.5', '0.708333333', '0.541666667',
#        '0.583333333'], dtype=object)

# %%
error_Time_Orderd = (
    ~data['Time_Orderd'].astype(str).str.contains(':', na=False)
    ) & (data['Time_Orderd'].notna())

converted_hours = (
    pd.to_numeric(data.loc[error_Time_Orderd, 'Time_Orderd']) * 24
).round().astype(int)

# %%
data.loc[error_Time_Orderd, 'Time_Orderd'] = (
    converted_hours.astype(str).str.zfill(2) + ':00'
)

# %%
data['Time_Orderd'] = data['Time_Orderd'].str.replace(r'^24:','00:',regex=True )
data['Time_Orderd'] = data['Time_Orderd'].str.slice(0,5)

# %%
data['Time_Orderd'].unique()
# Out:
# array(['21:55', '14:55', '17:30', '09:20', '19:50', '20:25', '20:30',
#        '20:40', '21:15', '20:20', '22:30', '08:15', '19:30', '12:25',
#        '18:35', '20:35', '23:20', '21:20', '23:35', '22:35', '23:25',
#        '13:35', '21:35', '18:55', '14:15', '11:00', '09:45', '08:40',
#        '23:00', '17:25', nan, '19:45', '19:10', '10:55', '21:40', '19:00',
#        '16:45', '11:30', '15:10', '22:45', '22:10', '20:45', '22:50',
#        '17:55', '09:25', '20:15', '22:25', '22:40', '23:50', '15:25',
#        '10:20', '20:55', '10:40', '15:55', '20:10', '12:10', '15:30',
#        '10:35', '21:10', '20:50', '12:35', '21:00', '23:40', '18:15',
#        '18:20', '11:45', '12:45', '23:30', '10:50', '21:25', '10:10',
#        '17:50', '22:20', '12:40', '23:55', '10:25', '08:45', '23:45',
#        '19:55', '22:15', '23:10', '09:15', '18:25', '18:45', '16:50',
#        '00:00', '14:20', '10:15', '08:50', '09:00', '17:45', '16:35',
#        '08:30', '21:45', '19:40', '14:50', '18:10', '12:20', '12:50',
#        '09:10', '12:30', '17:10', '19:15', '17:20', '18:30', '13:10',
#        '19:35', '09:50', '15:00', '20:00', '10:30', '09:40', '15:35',
#        '16:55', '22:55', '16:00', '18:00', '17:15', '21:30', '18:40',
#        '11:10', '13:50', '10:00', '21:50', '11:50', '13:30', '22:00',
#        '08:25', '11:20', '11:55', '09:30', '08:20', '08:10', '11:40',
#        '23:15', '19:20', '12:15', '11:35', '11:15', '17:35', '17:40',
#        '14:40', '18:50', '11:25', '14:25', '12:00', '16:10', '19:25',
#        '08:55', '13:40', '17:00', '09:35', '08:35', '16:15', '13:20',
#        '15:50', '15:20', '16:20', '14:30', '15:45', '16:40', '13:00',
#        '12:55', '10:45', '13:25', '09:55', '15:15', '13:15', '14:00',
#        '15:40', '16:25', '14:10', '13:45', '13:55', '14:35', '16:30',
#        '14:45'], dtype=object)

# %% [markdown]
# <h3 style="text-align: start; color: wheat;">
#    Time_Order_picked
# </h3>

# %%
in_correct_time_1 = data[~data['Time_Order_picked'].astype(str).str.contains(':', na=False)]

in_correct_time_1['Time_Order_picked'].unique()
# Out:
# array(['0.458333333', '0.75', '0.958333333', '0.916666667', '0.875',
#        '0.375', '0.833333333', '0.708333333', '0.625', '1', '0.791666667',
#        '0.5', '0.541666667', '0.416666667', '0.583333333', '0.666666667'],
#       dtype=object)

# %%
error_Time_Order_picked = (
        ~ data['Time_Order_picked'].astype(str).str.contains(':',na=False)
        ) & ( data['Time_Order_picked'].notna() )

convert_hours =  (pd.to_numeric(data.loc[error_Time_Order_picked,'Time_Order_picked']) * 24
                 ).round().astype(int)

# %%
data.loc[error_Time_Order_picked, 'Time_Order_picked'] = (
    convert_hours.astype(str).str.zfill(2) + ':00'
)

# %%
data['Time_Order_picked'] = data['Time_Order_picked'].str.replace(r'^24:','00:',regex=True )
data['Time_Order_picked'] = data['Time_Order_picked'].str.slice(0,5)

# %%
data['Time_Order_picked'].unique()
# Out:
# array(['22:10', '15:05', '17:40', '09:30', '20:05', '20:35', '15:10',
#        '20:40', '20:50', '21:30', '20:25', '22:45', '08:30', '19:45',
#        '12:30', '18:50', '23:30', '21:35', '23:45', '22:50', '22:40',
#        '23:35', '13:40', '21:45', '19:10', '14:25', '11:10', '09:55',
#        '08:55', '23:10', '17:30', '18:35', '19:50', '19:25', '11:00',
#        '19:15', '16:55', '11:40', '15:15', '22:55', '22:25', '20:55',
#        '23:05', '18:00', '23:00', '09:40', '20:20', '22:35', '22:00',
#        '23:55', '15:40', '10:30', '21:00', '10:50', '16:05', '20:15',
#        '12:15', '15:45', '22:15', '10:45', '15:30', '00:05', '21:25',
#        '12:45', '21:15', '18:20', '18:25', '11:50', '12:50', '10:55',
#        '21:40', '10:20', '17:55', '23:50', '12:55', '00:10', '10:40',
#        '09:00', '20:45', '20:00', '23:15', '22:20', '21:05', '17:00',
#        '00:15', '21:20', '14:35', '10:25', '09:05', '16:50', '08:40',
#        '23:40', '21:50', '19:55', '15:00', '10:35', '09:25', '17:20',
#        '19:30', '17:25', '20:10', '00:00', '17:35', '19:00', '19:05',
#        '13:20', '17:50', '18:05', '19:20', '10:05', '09:10', '21:55',
#        '19:40', '18:10', '09:50', '15:50', '18:30', '18:15', '16:15',
#        '11:15', '21:10', '22:30', '15:20', '18:40', '23:20', '11:25',
#        '13:55', '18:45', '22:05', '11:55', '18:55', '09:45', '17:15',
#        '12:05', '12:00', '19:35', '08:25', '11:05', '15:35', '12:40',
#        '12:25', '08:20', '23:25', '16:10', '13:45', '08:15', '08:45',
#        '20:30', '13:00', '11:20', '08:50', '14:45', '17:45', '10:00',
#        '08:35', '12:10', '11:35', '14:30', '10:15', '17:05', '10:10',
#        '09:35', '11:30', '16:25', '09:15', '13:35', '15:55', '13:10',
#        '13:05', '11:45', '16:20', '16:30', '16:45', '09:20', '13:25',
#        '14:15', '14:05', '16:35', '16:40', '13:30', '14:40', '12:20',
#        '13:50', '17:10', '15:25', '14:20', '12:35', '14:00', '14:10',
#        '14:55', '13:15', '14:50', '16:00'], dtype=object)

# %% [markdown]
# <h3 style="text-align: start; color: wheat;">
#   Restaurant_latitude, Restaurant_longitude,Delivery_location_latitude,Delivery_location_longitude
# </h3>

# %%
data['Restaurant_latitude'].unique()
# Out:
# array([ 30.327968,  10.003064,  18.56245 ,  30.899584,  26.463504,
#         19.176269,  12.311072,  18.592718,  17.426228,  22.552672,
#         18.563934,  23.357804,  11.003669,  12.986047,  19.221315,
#         13.005801,  26.849596,  21.160522,  12.934179,  18.51421 ,
#         11.022477,  21.160437,  15.51315 ,  15.561295,   0.      ,
#         18.55144 ,  18.593481,  21.173343,  17.451976,  12.972532,
#         13.064181,  19.121999,  21.149569,  19.091458,  22.539129,
#         12.970324,  21.175975,  23.369746,  12.914264,  11.003681,
#        -21.173343, -26.483042, -21.183434, -22.310526, -22.74806 ,
#        -12.304569, -19.1093  , -19.879631, -19.874449, -10.020683,
#        -19.875337, -26.911927, -23.416792, -21.186608, -12.323994,
#        -12.933284, -17.450851, -19.875016, -22.569358, -12.284747,
#        -23.355164, -18.592718, -27.201725, -22.311358, -19.207222,
#        -13.022394, -21.149569, -22.538731, -27.161661, -27.160832,
#        -13.066762, -10.96185 , -12.935662, -17.428294, -30.359722,
#        -11.022169, -30.885814, -25.451517, -22.651847, -22.547186,
#        -26.474133, -30.893384, -22.761226, -11.001852, -30.327968,
#        -22.745536, -17.455894, -26.481547, -22.32    , -23.371292,
#        -18.563934, -30.905562, -25.450377, -22.515082, -22.725748,
#        -23.351058, -26.473698, -23.333017, -30.873988,  -9.982834,
#        -22.514119, -21.170798, -12.979166, -19.065838, -19.876428,
#        -13.02978 , -12.310972, -22.307898, -21.170096, -21.186438,
#         -9.960846, -10.994136, -21.175104, -15.303897, -11.022477,
#        -26.846156, -25.457116, -26.905287, -21.149834, -30.328174,
#        -30.362686, -19.055831, -22.5491  , -26.471529, -12.934365,
#        -30.893244, -19.888716, -12.975377, -22.551084, -15.561295,
#        -22.695207, -26.956431,  -9.979186, -11.006686, -12.323225,
#        -13.026286, -25.454697, -23.357804, -19.880256, -13.081878,
#        -10.027014, -18.543626, -10.003064, -22.552996, -18.530963,
#        -19.866969, -22.75004 , -26.469003, -26.766536, -12.326356,
#        -22.577821, -22.569367, -23.232357, -13.091809, -12.933298,
#        -22.533662, -22.745049, -26.921411, -23.374878, -27.158822,
#        -12.906229, -13.044694, -13.045479, -12.98041 , -26.90294 ,
#        -23.369746, -19.875908, -26.479108, -30.892978, -23.232537,
#        -22.514585, -22.751234, -17.426228, -17.411028, -18.636215,
#        -15.56155 , -19.254567, -25.457687, -15.506205, -15.516833,
#        -11.02091 , -12.3085  , -26.47    , -19.003517, -30.890184,
#        -22.760072, -22.722634, -19.12663 , -22.753839, -21.173493,
#        -17.430448, -12.939496, -18.56245 , -22.308096, -23.264015,
#        -26.482581, -15.498603, -18.51421 , -12.975996, -19.874733,
#        -15.49395 , -12.978453])

# %% [raw]
# Any records showing negative latitude or longitude are likely data entry errors. By converting these to absolute values

# %%
columns_change = ['Restaurant_latitude','Restaurant_longitude','Delivery_location_latitude','Delivery_location_longitude']
data[columns_change] = data[columns_change].abs()

# %%
# Latitude: (8.4) to (37.6) .Longitude: (68.7) to (97.2)
# Indian latitude and longitude range

lat_range = (8.4, 37.6)
lon_range = (68.7, 97.2)

# Checking all four coordinate columns
coords = {
    'Res_Lat': 'Restaurant_latitude',
    'Res_Lon': 'Restaurant_longitude',
    'Del_Lat': 'Delivery_location_latitude',
    'Del_Lon': 'Delivery_location_longitude'
}

for label, col in coords.items():
    if 'Lat' in label:
        invalid = data[~data[col].between(*lat_range)].shape[0]
    else:
        invalid = data[~data[col].between(*lon_range)].shape[0]
    
    print(f"{label} errors: {invalid}")
# Out:
# Res_Lat errors: 3640
# Res_Lon errors: 3640
# Del_Lat errors: 3640
# Del_Lon errors: 3640

# %%
data.shape
# Out:
# (45584, 20)

# %%
# Only keeping valid coordinates. Keeping invalid ones would cause extreme errors in distance calculations

valid_coords = (
    data['Restaurant_latitude'].between(8.4, 37.6) &
    data['Restaurant_longitude'].between(68.7, 97.2) &
    data['Delivery_location_latitude'].between(8.4, 37.6) &
    data['Delivery_location_longitude'].between(68.7, 97.2)
)
# changing index for all data set
data = data[valid_coords].reset_index(drop=True)

# %%
data.shape
# Out:
# (41944, 20)

# %%
data.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude Order_Date Time_Orderd Time_Order_picked  \
# 0                    78.116106 2022-02-12       21:55             22:10
# 1                    76.347589 2022-02-13       14:55             15:05
# 2                    74.006619 2022-03-04       17:30             17:40
# 3                    75.829346 2022-02-13       09:20             09:30
# 4                    80.502929 2022-02-14       19:50             20:05
#
#   Weather_conditions Road_traffic_density  Vehicle_condition Type_of_order  \
# 0                Fog                  Jam                  2         Snack
# 1             Stormy                 High                  1          Meal
# 2         Sandstorms               Medium                  1        Drinks
# 3         Sandstorms                  Low                  0        Buffet
# 4                Fog                  Jam                  1         Snack
#
#   Type_of_vehicle  multiple_deliveries Festival           City  \
# 0      motorcycle                  3.0       No  Metropolitian
# 1      motorcycle                  1.0       No  Metropolitian
# 2         scooter                  1.0       No  Metropolitian
# 3      motorcycle                  0.0       No  Metropolitian
# 4         scooter                  1.0       No  Metropolitian
#
#    Time_taken (min)
# 0                46
# 1                23
# 2                21
# 3                20
# 4                41

# %% [markdown]
# <h3 style="text-align: start; color: wheat;">
#   Delivery_person_Age
# </h3>

# %%
data['Delivery_person_Age'].unique()
# Out:
# array([36., 21., 23., 34., 24., 29., 35., 33., 25., 31., 37., 27., 32.,
#        26., 38., 20., 22., nan, 28., 39., 30., 15., 50.])

# %%
data[data['Delivery_person_Age'] <= 18]
# Out:
#            ID Delivery_person_ID  Delivery_person_Age  \
# 2172    0x564      JAPRES15DEL03                 15.0
# 2647    0xcd0    INDORES010DEL03                 15.0
# 2691    0x91a      SURRES17DEL03                 15.0
# 5397    0x474     CHENRES15DEL03                 15.0
# 8404    0x73f     BANGRES05DEL01                 15.0
# 10014  0x1b49      MUMRES14DEL02                 15.0
# 10220   0x40b      SURRES12DEL01                 15.0
# 11109   0x523     INDORES03DEL02                 15.0
# 14634   0x550     CHENRES08DEL02                 15.0
# 14779   0x58c      MUMRES02DEL01                 15.0
# 15122   0xe4c      MYSRES05DEL03                 15.0
# 19531   0x3fc     BANGRES16DEL02                 15.0
# 20514   0x3ed   RANCHIRES09DEL01                 15.0
# 21625  0x616c      SURRES07DEL02                 15.0
# 21768  0x1ea0     BANGRES17DEL02                 15.0
# 21786   0x3f7     CHENRES04DEL01                 15.0
# 23823   0xbb3     CHENRES15DEL03                 15.0
# 24521   0x730     INDORES15DEL02                 15.0
# 24786   0x6e0     CHENRES06DEL03                 15.0
# 24966   0x3f2     BANGRES02DEL02                 15.0
# 25728   0x681     CHENRES07DEL03                 15.0
# 25785   0x406     PUNERES14DEL01                 15.0
# 27291  0x137e      MYSRES19DEL02                 15.0
# 28723  0x32aa      JAPRES11DEL01                 15.0
# 29403  0x4240     PUNERES05DEL02                 15.0
# 30548   0x622     CHENRES03DEL02                 15.0
# 32161   0x85c    COIMBRES17DEL02                 15.0
# 33144   0xdc0    COIMBRES03DEL03                 15.0
# 34125   0x451      HYDRES14DEL03                 15.0
# 34664   0x424     PUNERES20DEL02                 15.0
# 35948   0x4a6    COIMBRES07DEL02                 15.0
# 35957  0x1144      MYSRES05DEL01                 15.0
# 37067   0x442     CHENRES16DEL02                 15.0
# 37944   0x49c    COIMBRES14DEL02                 15.0
# 41288   0x8d4     CHENRES02DEL02                 15.0
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
#
#
#       Time_Orderd Time_Order_picked Weather_conditions Road_traffic_density  \
# 2172          NaN             17:20                NaN                  NaN
# 2647          NaN             20:30                NaN                  NaN
# 2691          NaN             22:10                NaN                  NaN
# 5397          NaN             20:50                NaN                  NaN
# 8404          NaN             23:25                NaN                  NaN
# 10014         NaN             20:55                NaN                  NaN
# 10220         NaN             11:30                NaN                  NaN
# 11109         NaN             21:15                NaN                  NaN
# 14634         NaN             18:10                NaN                  NaN
# 14779         NaN             12:05                NaN                  NaN
# 15122         NaN             20:00                NaN                  NaN
# 19531         NaN             17:15                NaN                  NaN
# 20514         NaN             21:35                NaN                  NaN
# 21625         NaN             17:30                NaN                  NaN
# 21768         NaN             17:40                NaN                  NaN
# 21786         NaN             22:40                NaN                  NaN
# 23823         NaN             22:50                NaN                  NaN
# 24521         NaN             17:35                NaN                  NaN
# 24786         NaN             18:20                NaN                  NaN
# 24966         NaN             21:45                NaN                  NaN
# 25728         NaN             21:50                NaN                  NaN
# 25785         NaN             19:30                NaN                  NaN
# 27291         NaN             09:35                NaN                  NaN
# 28723         NaN             10:05                NaN                  NaN
# 29403         NaN             21:25                NaN                  NaN
# 30548         NaN             11:50                NaN                  NaN
# 32161         NaN             09:10                NaN                  NaN
# 33144         NaN             18:55                NaN                  NaN
# 34125         NaN             19:05                NaN                  NaN
# 34664         NaN             20:25                NaN                  NaN
# 35948         NaN             19:55                NaN                  NaN
# 35957         NaN             22:10                NaN                  NaN
# 37067         NaN             23:05                NaN                  NaN
# 37944         NaN             23:45                NaN                  NaN
# 41288         NaN             18:00                NaN                  NaN
#
#        Vehicle_condition Type_of_order   Type_of_vehicle  multiple_deliveries  \
# 2172                   3          Meal        motorcycle                  0.0
# 2647                   3         Snack           scooter                  1.0
# 2691                   3        Buffet           bicycle                  1.0
# 5397                   3        Drinks           bicycle                  1.0
# 8404                   3        Buffet        motorcycle                  2.0
# 10014                  3        Buffet        motorcycle                  1.0
# 10220                  3          Meal           scooter                  1.0
# 11109                  3        Buffet           bicycle                  0.0
# 14634                  3         Snack           bicycle                  0.0
# 14779                  3         Snack           scooter                  0.0
# 15122                  3          Meal  electric_scooter                  0.0
# 19531                  3        Drinks  electric_scooter                  0.0
# 20514                  3        Buffet  electric_scooter                  2.0
# 21625                  3         Snack           scooter                  1.0
# 21768                  3        Drinks           bicycle                  1.0
# 21786                  3         Snack  electric_scooter                  1.0
# 23823                  3        Drinks           scooter                  0.0
# 24521                  3         Snack  electric_scooter                  1.0
# 24786                  3          Meal  electric_scooter                  1.0
# 24966                  3        Drinks  electric_scooter                  0.0
# 25728                  3        Buffet  electric_scooter                  1.0
# 25785                  3        Buffet           scooter                  1.0
# 27291                  3        Drinks           scooter                  1.0
# 28723                  3         Snack  electric_scooter                  1.0
# 29403                  3          Meal           bicycle                  0.0
# 30548                  3        Buffet           scooter                  0.0
# 32161                  3         Snack           scooter                  1.0
# 33144                  3          Meal        motorcycle                  1.0
# 34125                  3        Buffet  electric_scooter                  1.0
# 34664                  3        Buffet           scooter                  1.0
# 35948                  3        Drinks  electric_scooter                  0.0
# 35957                  3         Snack  electric_scooter                  0.0
# 37067                  3         Snack           bicycle                  0.0
# 37944                  3          Meal           scooter                  0.0
# 41288                  3         Snack  electric_scooter                  1.0
#
#       Festival           City  Time_taken (min)
# 2172        No          Urban                15
# 2647        No  Metropolitian                29
# 2691        No  Metropolitian                20
# 5397        No  Metropolitian                25
# 8404        No  Metropolitian                34
# 10014       No  Metropolitian                39
# 10220       No          Urban                27
# 11109       No  Metropolitian                28
# 14634       No  Metropolitian                17
# 14779       No  Metropolitian                23
# 15122       No          Urban                24
# 19531       No  Metropolitian                28
# 20514      Yes  Metropolitian                44
# 21625       No  Metropolitian                32
# 21768       No  Metropolitian                23
# 21786       No          Urban                15
# 23823       No  Metropolitian                27
# 24521       No  Metropolitian                27
# 24786       No          Urban                21
# 24966       No          Urban                20
# 25728       No  Metropolitian                27
# 25785       No  Metropolitian                38
# 27291       No  Metropolitian                13
# 28723       No          Urban                19
# 29403       No  Metropolitian                21
# 30548       No  Metropolitian                33
# 32161       No  Metropolitian                19
# 33144       No  Metropolitian                28
# 34125       No          Urban                30
# 34664       No          Urban                30
# 35948       No  Metropolitian                24
# 35957       No  Metropolitian                30
# 37067       No  Metropolitian                25
# 37944       No  Metropolitian                25
# 41288       No          Urban                26

# %%
len(data[data['Delivery_person_Age'] <= 18])
# Out:
# 35

# %% [raw]
# Drop these rows because Age 15 is below the legal working limit, and those specific records are highly corrupted, missing critical data like Time_Orderd, Weather, and Traffic. Removing them ensures your model learns from realistic, high-quality delivery patterns.

# %%
data = data[data['Delivery_person_Age'] >= 18].reset_index(drop=True)

# %%
data['Delivery_person_Age'] = data['Delivery_person_Age'].astype(int)

# %%
data[data['Delivery_person_Age'] <= 18].head()
# Out:
# Empty DataFrame
# Columns: [ID, Delivery_person_ID, Delivery_person_Age, Delivery_person_Ratings, Restaurant_latitude, Restaurant_longitude, Delivery_location_latitude, Delivery_location_longitude, Order_Date, Time_Orderd, Time_Order_picked, Weather_conditions, Road_traffic_density, Vehicle_condition, Type_of_order, Type_of_vehicle, multiple_deliveries, Festival, City, Time_taken (min)]
# Index: []

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40190 entries, 0 to 40189
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           40190 non-null  object
#  1   Delivery_person_ID           40190 non-null  object
#  2   Delivery_person_Age          40190 non-null  int64
#  3   Delivery_person_Ratings      40146 non-null  float64
#  4   Restaurant_latitude          40190 non-null  float64
#  5   Restaurant_longitude         40190 non-null  float64
#  6   Delivery_location_latitude   40190 non-null  float64
#  7   Delivery_location_longitude  40190 non-null  float64
#  8   Order_Date                   40190 non-null  datetime64[ns]
#  9   Time_Orderd                  40144 non-null  object
#  10  Time_Order_picked            40190 non-null  object
#  11  Weather_conditions           40144 non-null  object
#  12  Road_traffic_density         40144 non-null  object
#  13  Vehicle_condition            40190 non-null  int64
#  14  Type_of_order                40190 non-null  object
#  15  Type_of_vehicle              40190 non-null  object
#  16  multiple_deliveries          39343 non-null  float64
#  17  Festival                     39985 non-null  object
#  18  City                         39137 non-null  object
#  19  Time_taken (min)             40190 non-null  int64
# dtypes: datetime64[ns](1), float64(6), int64(3), object(10)
# memory usage: 6.1+ MB

# %% [markdown]
# <h3 style="text-align: start; color: wheat;">
#   Delivery_person_Ratings
# </h3>

# %%
data['Delivery_person_Ratings'].unique()
# Out:
# array([4.2, 4.7, 4.3, 4.5, 4. , 4.9, 4.1, 5. , 4.8, 4.6, 4.4, 3.8, nan,
#        3.9, 3.7, 2.6, 3.5, 2.5, 3.6, 3.1, 2.7, 3.3, 6. , 3.4, 3.2, 2.8,
#        2.9, 3. ])

# %%
data[data['Delivery_person_Ratings'] > 5 ]
# Out:
#            ID Delivery_person_ID  Delivery_person_Age  \
# 3136    0x46d     BANGRES05DEL01                   50
# 4120    0x493      HYDRES17DEL01                   50
# 4528    0x4f2      JAPRES08DEL01                   50
# 4697    0x430     BANGRES19DEL01                   50
# 4950   0xbef1      AGRRES13DEL02                   50
# 5613    0x427      JAPRES06DEL02                   50
# 6176    0x3eb      MYSRES15DEL02                   50
# 8364    0x3f0    BANGRES010DEL01                   50
# 8397    0x3ef   RANCHIRES13DEL01                   50
# 8901    0x5b0      MYSRES04DEL01                   50
# 10828   0x940      SURRES02DEL02                   50
# 11677   0x490    COIMBRES03DEL02                   50
# 12030   0x434   RANCHIRES01DEL02                   50
# 12431   0x3f6      MYSRES06DEL02                   50
# 13150   0x421     CHENRES19DEL01                   50
# 13184   0x43c      HYDRES14DEL01                   50
# 14826   0x3fa   RANCHIRES06DEL02                   50
# 15131   0x400    COIMBRES07DEL01                   50
# 15637   0x412    CHENRES010DEL01                   50
# 16769  0xc363      BHPRES08DEL03                   50
# 17129   0x3fb     INDORES02DEL03                   50
# 17915  0xd0bc      ALHRES01DEL02                   50
# 18857   0x810      HYDRES06DEL01                   50
# 19830  0xc7d6      ALHRES08DEL03                   50
# 20685  0x1060     BANGRES05DEL03                   50
# 21435   0x420      SURRES13DEL01                   50
# 22031  0xbf34      KNPRES16DEL02                   50
# 22358   0x40c    COIMBRES08DEL03                   50
# 23043   0x694   RANCHIRES09DEL02                   50
# 24042   0x3f4    COIMBRES20DEL02                   50
# 24199   0x3ea      MUMRES20DEL03                   50
# 25009   0x3fd     BANGRES13DEL01                   50
# 25580   0x404     CHENRES04DEL01                   50
# 26059   0x480     BANGRES15DEL01                   50
# 26980  0xbf12      BHPRES20DEL03                   50
# 27297   0x4cc      MUMRES20DEL01                   50
# 28506  0xbf33      KNPRES03DEL03                   50
# 29581  0xbf01      KOLRES06DEL02                   50
# 30598  0xbf76      AGRRES20DEL03                   50
# 33526  0xbef2      DEHRES13DEL01                   50
# 33537   0x466     CHENRES14DEL02                   50
# 34083   0x5e0      MUMRES07DEL03                   50
# 35473   0x3e9      MYSRES04DEL03                   50
# 37008  0xbef4      KNPRES19DEL03                   50
# 37095   0x5fc     INDORES11DEL03                   50
# 37768   0x53e     BANGRES12DEL01                   50
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
#
# 24199       No  Metropolitian                18
# 25009       No  Metropolitian                28
# 25580       No  Metropolitian                20
# 26059       No  Metropolitian                15
# 26980       No  Metropolitian                39
# 27297       No          Urban                30
# 28506       No            NaN                17
# 29581       No  Metropolitian                28
# 30598       No          Urban                16
# 33526       No  Metropolitian                25
# 33537       No  Metropolitian                14
# 34083       No          Urban                26
# 35473       No  Metropolitian                40
# 37008       No  Metropolitian                15
# 37095       No  Metropolitian                28
# 37768       No  Metropolitian                19

# %%
len(data[data['Delivery_person_Ratings'] > 5 ])
# Out:
# 46

# %% [raw]
# Invalid Value: It exceeds the logical maximum rating of 5.0.
# Error Indicator: It identifies rows where the actual data was never recorded.
# Data Cleaning: These rows should be removed to prevent them from skewing your averages and analysis.

# %%
data = data[data['Delivery_person_Ratings'] <= 5].reset_index(drop=True)

# %%
data[data['Delivery_person_Ratings'] > 5 ]
# Out:
# Empty DataFrame
# Columns: [ID, Delivery_person_ID, Delivery_person_Age, Delivery_person_Ratings, Restaurant_latitude, Restaurant_longitude, Delivery_location_latitude, Delivery_location_longitude, Order_Date, Time_Orderd, Time_Order_picked, Weather_conditions, Road_traffic_density, Vehicle_condition, Type_of_order, Type_of_vehicle, multiple_deliveries, Festival, City, Time_taken (min)]
# Index: []

# %%
data.shape
# Out:
# (40100, 20)

# %% [markdown]
# <h3 style="text-align: start; color: wheat;">
#   Weather_conditions
# </h3>

# %%
data['Weather_conditions'].unique()
# Out:
# array(['Fog', 'Stormy', 'Sandstorms', 'Windy', 'Cloudy', 'Sunny'],
#       dtype=object)

# %%
data['Weather_conditions'] = data['Weather_conditions'].str.strip()

# %% [markdown]
# <h3 style="text-align: start; color: wheat;">
#   Road_traffic_density
# </h3>

# %%
data['Road_traffic_density'].unique()
# Out:
# array(['Jam', 'High', 'Medium', 'Low'], dtype=object)

# %%
data['Road_traffic_density'] = data['Road_traffic_density'].str.strip()

# %% [markdown]
# <h3 style="text-align: start; color: wheat;">
#   Festival
# </h3>

# %%
data['Festival'].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
data['Festival'] = data['Festival'].str.strip()

# %% [markdown]
# <h3 style="text-align: start; color: wheat;">
#  City
# </h3>

# %%
data['City'].unique()
# Out:
# array(['Metropolitian', 'Urban', nan, 'Semi-Urban'], dtype=object)

# %%
data['City'] = data['City'].replace(
    'Metropolitian',
    'Metropolitan'
)

# %%
data['City'].unique()
# Out:
# array(['Metropolitan', 'Urban', nan, 'Semi-Urban'], dtype=object)

# %% [markdown]
# ## Rename columns

# %%
data.columns
# Out:
# Index(['ID', 'Delivery_person_ID', 'Delivery_person_Age',
#        'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Order_Date', 'Time_Orderd',
#        'Time_Order_picked', 'Weather_conditions', 'Road_traffic_density',
#        'Vehicle_condition', 'Type_of_order', 'Type_of_vehicle',
#        'multiple_deliveries', 'Festival', 'City', 'Time_taken (min)'],
#       dtype='object')

# %%
data = data.rename(columns={
        'Time_Orderd': 'Time_Ordered',
        'Time_taken (min)': 'Delivery_time',
        'multiple_deliveries' : 'Multiple_deliveries'
    })

# %%
data.columns
# Out:
# Index(['ID', 'Delivery_person_ID', 'Delivery_person_Age',
#        'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Order_Date', 'Time_Ordered',
#        'Time_Order_picked', 'Weather_conditions', 'Road_traffic_density',
#        'Vehicle_condition', 'Type_of_order', 'Type_of_vehicle',
#        'Multiple_deliveries', 'Festival', 'City', 'Delivery_time'],
#       dtype='object')

# %%
data.describe().T
# Out:
#                                count                           mean  \
# Delivery_person_Age          40100.0                       29.55409
# Delivery_person_Ratings      40100.0                        4.63398
# Restaurant_latitude          40100.0                      18.910301
# Restaurant_longitude         40100.0                      76.917509
# Delivery_location_latitude   40100.0                       18.97393
# Delivery_location_longitude  40100.0                      76.981138
# Order_Date                     40100  2022-03-14 04:59:07.930174464
# Vehicle_condition            40100.0                       0.999601
# Multiple_deliveries          39254.0                       0.744306
# Delivery_time                40100.0                      26.312469
#
#                                              min                  25%  \
# Delivery_person_Age                         20.0                 25.0
# Delivery_person_Ratings                      2.5                  4.5
# Restaurant_latitude                     9.957144            12.986047
# Restaurant_longitude                   72.768726            73.898366
# Delivery_location_latitude              9.967144            13.065801
# Delivery_location_longitude            72.778726            73.940492
# Order_Date                   2022-02-11 00:00:00  2022-03-05 00:00:00
# Vehicle_condition                            0.0                  0.0
# Multiple_deliveries                          0.0                  0.0
# Delivery_time                               10.0                 19.0
#
#                                              50%                  75%  \
# Delivery_person_Age                         30.0                 35.0
# Delivery_person_Ratings                      4.7                  4.9
# Restaurant_latitude                    19.065838            22.751234
# Restaurant_longitude                   76.618203            78.347554
# Delivery_location_latitude             19.123649             22.82004
# Delivery_location_longitude            76.662449            78.402621
# Order_Date                   2022-03-15 00:00:00  2022-03-27 00:00:00
# Vehicle_condition                            1.0                  2.0
# Multiple_deliveries                          1.0                  1.0
# Delivery_time                               26.0                 32.0
#
#                                              max       std
# Delivery_person_Age                         39.0  5.760046
# Delivery_person_Ratings                      5.0  0.314914
# Restaurant_latitude                    30.914057  5.470029
# Restaurant_longitude                   88.433452  3.498139
# Delivery_location_latitude             31.054057  5.471837
# Delivery_location_longitude            88.563452  3.498342
# Order_Date                   2022-04-06 00:00:00       NaN
# Vehicle_condition                            2.0  0.816334
# Multiple_deliveries                          3.0  0.572571
# Delivery_time                               54.0  9.371547

# %%
data.describe(include='object')
# Out:
#             ID Delivery_person_ID Time_Ordered Time_Order_picked  \
# count    40100              40100        40100             40100
# unique   40100               1170          176               193
# top     0x5fb2     PUNERES01DEL01        21:55             21:30
# freq         1                 65          420               445
#
#        Weather_conditions Road_traffic_density Type_of_order Type_of_vehicle  \
# count               40100                40100         40100           40100
# unique                  6                    4             4               3
# top                   Fog                  Low         Snack      motorcycle
# freq                 6804                13738         10129           23524
#
#        Festival          City
# count     39896         39050
# unique        2             3
# top          No  Metropolitan
# freq      39113         30024

# %%
data.nunique()
# Out:
# ID                             40100
# Delivery_person_ID              1170
# Delivery_person_Age               20
# Delivery_person_Ratings           26
# Restaurant_latitude              388
# Restaurant_longitude             388
# Delivery_location_latitude      4354
# Delivery_location_longitude     4354
# Order_Date                        44
# Time_Ordered                     176
# Time_Order_picked                193
# Weather_conditions                 6
# Road_traffic_density               4
# Vehicle_condition                  3
# Type_of_order                      4
# Type_of_vehicle                    3
# Multiple_deliveries                4
# Festival                           2
# City                               3
# Delivery_time                     45
# dtype: int64

# %% [markdown]
# <h2 style="text-align: start; color: SteelBlue; text-transform: uppercase;">
#  Feature Engineering
# </h2>

# %% [raw]
# Feature engineering was performed to transform raw data into meaningful input features that improve machine learning model performance

# %% [markdown]
# <h3 style="text-align: start; color: wheat;">
#   Distance
# </h3>

# %% [raw]
# Features Used:
#     Restaurant_latitude
#     Restaurant_longitude
#     Delivery_location_latitude
#     Delivery_location_longitude

# %%
R = 6371

lat1 = np.radians(data['Restaurant_latitude'])
lon1 = np.radians(data['Restaurant_longitude'])
lat2 = np.radians(data['Delivery_location_latitude'])
lon2 = np.radians(data['Delivery_location_longitude'])

dlat = lat2 - lat1
dlon = lon2 - lon1

a = np.sin(dlat/2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2)**2
c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1-a))

data['Distance'] = R * c

# %%
data[['Distance']].head()
# Out:
#     Distance
# 0  10.280582
# 1   6.242319
# 2  13.787860
# 3   2.930258
# 4  19.396618

# %%
data['Distance'].sort_values(ascending= False)
# Out:
# 787      20.969489
# 22882    20.969489
# 13832    20.969489
# 14788    20.969045
# 14656    20.969045
#            ...
# 16208     1.465123
# 28316     1.465123
# 29099     1.465067
# 6501      1.465067
# 23451     1.465067
# Name: Distance, Length: 40100, dtype: float64

# %% [raw]
# Distance is an important factor affecting delivery duration.

# %% [markdown]
# <h3 style="text-align: start; color: wheat;">
#   Time_Slot
# </h3>

# %% [raw]
# Features Used :
#     Time_Ordered

# %%
data['Time_Ordered'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 40100 entries, 0 to 40099
# Series name: Time_Ordered
# Non-Null Count  Dtype
# --------------  -----
# 40100 non-null  object
# dtypes: object(1)
# memory usage: 313.4+ KB

# %%
data['Time_Ordered'] = pd.to_datetime(data['Time_Ordered'], format='%H:%M')
def assign_time_slot(time):
    if pd.isna(time):
        return 'Unknown'
    hour = time.hour
    if 5 <= hour < 12:
        return 'Morning'
    elif 12 <= hour < 17:
        return 'Afternoon'
    elif 17 <= hour < 21:
        return 'Evening'
    else:
        return 'Night'
data['Time_slot'] = data['Time_Ordered'].apply(assign_time_slot)

# %%
data['Time_slot'].value_counts()
# Out:
# Time_slot
# Evening      16394
# Night        12961
# Morning       7049
# Afternoon     3696
# Name: count, dtype: int64

# %% [markdown]
# <h3 style="text-align: start; color: wheat;">
#   Prepration_Time
# </h3>

# %% [raw]
# Features Used :
#     Time_Ordered
#     Time_Order_picked

# %%
data['Time_Ordered'] = pd.to_datetime(data['Time_Ordered'], format='%H:%M',errors='coerce')
data['Time_Order_picked'] = pd.to_datetime(data['Time_Order_picked'], format='%H:%M',errors='coerce')
data['Prepration_minute'] = (data['Time_Order_picked'] - data['Time_Ordered']).dt.total_seconds() / 60
data.loc[data['Prepration_minute'] < 0, 'Prepration_minute'] += 1440

# %%
data['Prepration_minute'] = data['Prepration_minute'].astype(int)

# %%
data['Prepration_minute'].value_counts()
# Out:
# Prepration_minute
# 5     13469
# 10    13318
# 15    13313
# Name: count, dtype: int64

# %% [markdown]
# <h3 style="text-align: start; color: wheat;">
#   Weekend
# </h3>

# %% [raw]
# Features Used :
#     Order_Date

# %%
data['Order_Date'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 40100 entries, 0 to 40099
# Series name: Order_Date
# Non-Null Count  Dtype
# --------------  -----
# 40100 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 313.4 KB

# %%
# Create a 1 for Sat/Sun and 0 for weekdays
data['Is_Weekend'] = data['Order_Date'].dt.dayofweek.isin([5, 6]).astype(int)

# %%
data[['Is_Weekend']].head()
# Out:
#    Is_Weekend
# 0           1
# 1           1
# 2           0
# 3           1
# 4           0

# %% [markdown]
# <h3 style="text-align: start; color: wheat;">
#   Peak_Hour
# </h3>

# %% [raw]
# Features Used :
#     Time_Ordered

# %%
hours = data['Time_Ordered'].dt.hour
lunch_hour = ( hours >= 11 ) & ( hours <= 14 )
dinner_hour = ( hours >= 18 ) & ( hours <= 21 )
data['Peak_hour'] = np.where( lunch_hour | dinner_hour, 'Peak Hour', 'Non-Peak Hour' )

# %%
data['Peak_hour'].value_counts()
# Out:
# Peak_hour
# Peak Hour        20820
# Non-Peak Hour    19280
# Name: count, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40100 entries, 0 to 40099
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           40100 non-null  object
#  1   Delivery_person_ID           40100 non-null  object
#  2   Delivery_person_Age          40100 non-null  int64
#  3   Delivery_person_Ratings      40100 non-null  float64
#  4   Restaurant_latitude          40100 non-null  float64
#  5   Restaurant_longitude         40100 non-null  float64
#  6   Delivery_location_latitude   40100 non-null  float64
#  7   Delivery_location_longitude  40100 non-null  float64
#  8   Order_Date                   40100 non-null  datetime64[ns]
#  9   Time_Ordered                 40100 non-null  datetime64[ns]
#  10  Time_Order_picked            40100 non-null  datetime64[ns]
#  11  Weather_conditions           40100 non-null  object
#  12  Road_traffic_density         40100 non-null  object
#  13  Vehicle_condition            40100 non-null  int64
#  14  Type_of_order                40100 non-null  object
#  15  Type_of_vehicle              40100 non-null  object
#  16  Multiple_deliveries          39254 non-null  float64
#  17  Festival                     39896 non-null  object
#  18  City                         39050 non-null  object
#  19  Delivery_time                40100 non-null  int64
#  20  Distance                     40100 non-null  float64
#  21  Time_slot                    40100 non-null  object
#  22  Prepration_minute            40100 non-null  int64
#  23  Is_Weekend                   40100 non-null  int64
#  24  Peak_hour                    40100 non-null  object
# dtypes: datetime64[ns](3), float64(7), int64(5), object(10)
# memory usage: 7.6+ MB

# %% [markdown]
# <h4 style="text-align: start; color:red; text-transform: uppercase;">
#   Final Features
# </h4>

# %%
new_features  = data[['Distance','Prepration_minute','Time_slot','Peak_hour','Is_Weekend']]
new_features.head()
# Out:
#     Distance  Prepration_minute  Time_slot      Peak_hour  Is_Weekend
# 0  10.280582                 15      Night      Peak Hour           1
# 1   6.242319                 10  Afternoon      Peak Hour           1
# 2  13.787860                 10    Evening  Non-Peak Hour           0
# 3   2.930258                 10    Morning  Non-Peak Hour           1
# 4  19.396618                 15    Evening      Peak Hour           0

# %%
# Numerical
data[['Delivery_person_Age','Delivery_person_Ratings','Vehicle_condition','Multiple_deliveries','Distance','Prepration_minute','Delivery_time']].head()
# Out:
#    Delivery_person_Age  Delivery_person_Ratings  Vehicle_condition  \
# 0                   36                      4.2                  2
# 1                   21                      4.7                  1
# 2                   23                      4.7                  1
# 3                   34                      4.3                  0
# 4                   24                      4.7                  1
#
#    Multiple_deliveries   Distance  Prepration_minute  Delivery_time
# 0                  3.0  10.280582                 15             46
# 1                  1.0   6.242319                 10             23
# 2                  1.0  13.787860                 10             21
# 3                  0.0   2.930258                 10             20
# 4                  1.0  19.396618                 15             41

# %%
# Categorical
data [[ 'Weather_conditions','Road_traffic_density','Type_of_order','Type_of_vehicle','Festival','City','Time_slot','Peak_hour' ]].head()
# Out:
#   Weather_conditions Road_traffic_density Type_of_order Type_of_vehicle  \
# 0                Fog                  Jam         Snack      motorcycle
# 1             Stormy                 High          Meal      motorcycle
# 2         Sandstorms               Medium        Drinks         scooter
# 3         Sandstorms                  Low        Buffet      motorcycle
# 4                Fog                  Jam         Snack         scooter
#
#   Festival          City  Time_slot      Peak_hour
# 0       No  Metropolitan      Night      Peak Hour
# 1       No  Metropolitan  Afternoon      Peak Hour
# 2       No  Metropolitan    Evening  Non-Peak Hour
# 3       No  Metropolitan    Morning  Non-Peak Hour
# 4       No  Metropolitan    Evening      Peak Hour

# %% [markdown]
# <h2 style="text-align: start; color: SteelBlue; text-transform: uppercase;">
#    Exploratory Data Analysis (EDA)
# </h2>

# %% [raw]
# Exploratory Data Analysis (EDA) was performed to understand the dataset structure, identify patterns, analyze feature distributions, detect outliers, and study the relationship between independent variables and delivery time. Both univariate and bivariate analysis techniques were used to gain meaningful insights from the data.

# %% [markdown]
# <h4 style="text-align: start; color:red; text-transform: uppercase;">
#    What is the distribution of delivery person age?
# </h4>

# %%
plt.figure(figsize=(15,5))
plt.title("Distribution of Delivery_person_Age")

plt.subplot(1,3,1)
sns.histplot(data['Delivery_person_Age'],color="royalblue")

plt.subplot(1,3,2)
sns.boxplot(x=data['Delivery_person_Age'],color="royalblue")

plt.subplot(1,3,3)
sns.distplot(data['Delivery_person_Age'], hist=False,color="royalblue")

plt.subplots_adjust(wspace=0.5,hspace=0)
plt.show()

# %% [raw]
# Delivery_person_Age is uniformly distributed between 20 and 39 years. The median age is around 30 years, with no significant skewness or outliers observed. The feature appears clean and balanced across all age groups.

# %% [markdown]
# <h4 style="text-align: start; color:red; text-transform: uppercase;">
#    What is the distribution of delivery time?
#    Are there outliers in delivery time?
# </h4>

# %%
plt.figure(figsize=(15,5))
plt.title("Distribution of Time_taken_min")
plt.subplot(1,3,1)
sns.histplot(data['Delivery_time'],color="royalblue")

plt.subplot(1,3,2)
sns.boxplot(x=data['Delivery_time'],color="royalblue")

plt.subplot(1,3,3)
sns.distplot(data['Delivery_time'], hist=False,color="royalblue")

plt.subplots_adjust(wspace=0.5,hspace=0)
plt.show()

# %% [raw]
# Time_taken_min shows a positively skewed distribution, with most deliveries completed between 20 and 30 minutes. A small number of higher delivery times were identified as statistical outliers in the boxplot; however, these values appear operationally realistic and were retained for analysis.
#
# While Zomato usually delivers within 30–50 minutes, the maximum time taken can vary significantly, often extending to 1 hour or more during peak hours, heavy rain, or when delivery partners are handling multiple orders at once

# %% [markdown]
# <h4 style="text-align: start; color:red; text-transform: uppercase;">
#  Does traffic density affect delivery time?
# </h4>

# %%
plt.figure(figsize=(15,5))
plt.title("Traffic Density on Delivery Time")
sns.boxplot(data=data, x='Road_traffic_density', y='Delivery_time',color="royalblue")
# Out:
# <Axes: title={'center': 'Traffic Density on Delivery Time'}, xlabel='Road_traffic_density', ylabel='Delivery_time'>

# %% [raw]
# The boxplot confirms a direct correlation between road traffic density and delivery time. 'Jam' conditions result in the highest median delivery times (approximately 32 minutes) and the widest variance, while 'Low' traffic conditions significantly reduce both the median time (to approximately 21 minutes) and the overall spread of data. Interestingly, 'High' traffic shows a tighter distribution but a higher median than 'Medium' traffic, indicating that while heavy traffic is predictable, it consistently delays deliveries compared to lighter road conditions

# %% [markdown]
# <h4 style="text-align: start; color:red; text-transform: uppercase;">
# Are delivery times higher during peak ordering hours?
# </h4>

# %%
plt.figure(figsize=(15,5))
plt.title("Delivery Time Distribution: Peak vs. Non-Peak Hours")
sns.boxplot( x='Peak_hour',y='Delivery_time',data=data,color="royalblue")
plt.show()

# %% [raw]
# Peak hours show greater variability and more extreme outliers, indicating a higher risk of 45+ minute delays during rush periods.

# %% [markdown]
# <h4 style="text-align: start; color:red; text-transform: uppercase;">
# Does weather affect delivery duration?
# </h4>

# %%
plt.figure(figsize=(15,5))
plt.title("Weather Conditions on Delivery Time")
sns.boxplot(data=data, x='Weather_conditions', y='Delivery_time', color="royalblue")
plt.show()

# %% [raw]
# Fog and Cloudy conditions result in the highest median delivery times.
# Sunny weather has the lowest median delivery time (around 22–23 minutes).
# Stormy, Sandstorms, and Windy conditions show very similar median delivery times, sitting right in the middle (around 26 minutes).
# These insights suggest that weather is a primary feature for the predictive model.

# %% [markdown]
# <h4 style="text-align: start; color:red; text-transform: uppercase;">
# Does delivery distance increase delivery time?
# </h4>

# %%
plt.figure(figsize=(15, 6))
plt.title("Relationship between Distance and Delivery Time")

# Using regplot to see the trend line
sns.regplot(data=data[data['Distance'] > 0], x='Distance', y='Delivery_time', 
            scatter_kws={'alpha': 0.3, 's': 1}, 
            line_kws={'color': 'red'})

plt.xlabel("Distance (km)")
plt.ylabel("Time Taken (min)")
plt.show()

# %% [raw]
# positive correlation between delivery distance and time taken, as indicated by the upward-sloping red trend line.This confirms that while distance is a key factor, external variables such as traffic density and weather conditions are equally critical in determining the final delivery time

# %% [markdown]
# <h4 style="text-align: start; color:red; text-transform: uppercase;">
# Does preparation time affect delivery duration?
# </h4>

# %%
data[['Prepration_minute']].head()
# Out:
#    Prepration_minute
# 0                 15
# 1                 10
# 2                 10
# 3                 10
# 4                 15

# %%
plt.figure(figsize=(12, 6))
plt.title("Preparation Time on Total Delivery Duration")
sns.boxplot(data=data, x='Prepration_minute', y='Delivery_time', color="royalblue")
plt.xlabel("Preparation Time (min)")
plt.ylabel("Total Delivery Time (min)")
plt.show()

# %% [raw]
# The bivariate analysis indicates that 'Preparation Time' is not a strong standalone predictor of total delivery time. The lack of a significant upward shift in medians across the 5, 10, and 15-minute intervals suggests that once an order is picked up, transit factors—such as traffic density and distance—become the dominant drivers of the final delivery duration

# %% [markdown]
# <h4 style="text-align: start; color:red; text-transform: uppercase;">
# Which vehicle type performs fastest?
# </h4>

# %%
plt.figure(figsize=(12, 6))
plt.title("Performance Distribution by Vehicle Type", fontsize=15)
sns.violinplot(data=data, x='Type_of_vehicle', y='Delivery_time', palette="Blues", inner="quartile")
plt.xlabel("Vehicle Type", fontsize=12)
plt.ylabel("Total Delivery Time (min)", fontsize=12)
plt.show()

# %% [raw]
# vehicle type does not significantly influence delivery duration.

# %% [markdown]
# <h4 style="text-align: start; color:red; text-transform: uppercase;">
# Does handling multiple deliveries increase delay?
# </h4>

# %%
plt.figure(figsize=(12, 6))
plt.title("Impact of Multiple Deliveries on Total Time", fontsize=15)
sns.boxplot(data=data, x='Multiple_deliveries', y='Delivery_time', color="royalblue")
plt.xlabel("Number of Deliveries Handled", fontsize=12)
plt.ylabel("Total Delivery Time (min)", fontsize=12)
plt.show()

# %% [raw]
# yes,Multiple Deliveries' is one of the most influential factors in delivery delays.

# %% [markdown]
# <h4 style="text-align: start; color:red; text-transform: uppercase;">
# Are festival deliveries slower?
# </h4>

# %%
plt.figure(figsize=(12, 6))
sns.kdeplot(data=data, x='Delivery_time', hue='Festival', fill=True, common_norm=False)
plt.title("Density of Delivery Times")
plt.show()

# %% [raw]
# the distribution for normal days peaks between 20-30 minutes, the festival distribution shows a significant shift toward the 35-45 minute range. This confirms that festivals are a major bottleneck for delivery efficiency, likely due to increased order volume and city-wide traffic congestion

# %% [markdown]
# <h4 style="text-align: start; color:red; text-transform: uppercase;">
# Which time slot has highest delivery time?
# </h4>

# %%
plt.figure(figsize=(12, 6))
plt.title("Average Delivery Time by Time Slot", fontsize=15)
sns.barplot(data=data, x='Time_slot', y='Delivery_time', hue='Road_traffic_density', 
            order=['Morning', 'Afternoon', 'Evening', 'Night'])
plt.xlabel("Time Slot", fontsize=12)
plt.ylabel("Avg Delivery Time (min)", fontsize=12)
# Out:
# Text(0, 0.5, 'Avg Delivery Time (min)')

# %% [raw]
# The interaction between time slots and traffic density reveals that Evening and Night periods experience the highest delivery durations,

# %% [markdown]
# <h4 style="text-align: start; color:red; text-transform: uppercase;">
# Which city has highest average delivery time?
# </h4>

# %%
avg_time = data.groupby('City')['Delivery_time'].mean().sort_values(ascending=False)

plt.figure(figsize=(12, 6))
plt.title("Average Delivery Time Across Different City Types", fontsize=15)
plt.xlabel("Average Delivery Time (min)", fontsize=12)
plt.ylabel("City Type", fontsize=12)
sns.barplot(x=avg_time.values, y=avg_time.index, palette='Reds_r')
plt.show()

# %% [raw]
# The high delivery time in Semi-Urban areas represents a potential logistical bottleneck. Even though these areas might have lower traffic density, the average delivery time is nearly double that of Urban areas, indicating that distance and infrastructure are the primary challenges here rather than traffic congestion

# %% [markdown]
# <h4 style="text-align: start; color:red; text-transform: uppercase;">
# Which features are most correlated with delivery time?
# </h4>

# %%
data.select_dtypes(exclude='object').columns
# Out:
# Index(['Delivery_person_Age', 'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Order_Date', 'Time_Ordered',
#        'Time_Order_picked', 'Vehicle_condition', 'Multiple_deliveries',
#        'Delivery_time', 'Distance', 'Prepration_minute', 'Is_Weekend'],
#       dtype='object')

# %%
columns = ['Delivery_person_Age', 'Delivery_person_Ratings', 'Vehicle_condition', 
        'Multiple_deliveries', 'Distance', 'Prepration_minute', 'Delivery_time']
plt.figure(figsize=(12, 6))
sns.heatmap(data[columns].corr(), annot=True, cmap='RdYlGn')
plt.title('Correlation Heatmap')
plt.show()

# %% [raw]
# Multiple_deliveries (0.39) and Delivery_person_Ratings (-0.36) as the most significant predictors of delivery time.Distance (0.32) and Delivery_person_Age (0.3) show moderate positive correlations, indicating that travel length and driver experience are key factors.

# %% [markdown]
# <h4 style="text-align: start; color:red; text-transform: uppercase;">
# Which combination of weather and traffic creates highest delays?
# </h4>

# %%
plt.figure(figsize=(12, 6))
plt.title("Impact of Weather and Traffic on Delivery Time", fontsize=15)
sns.barplot(data=data, x='Weather_conditions', y='Delivery_time', hue='Road_traffic_density')
plt.xlabel("Weather Conditions", fontsize=12) 
plt.ylabel("Avg Delivery Time (min)", fontsize=12)
plt.show()

# %% [raw]
# The highest delivery latencies occur during Foggy or Stormy conditions coupled with Jam traffic.

# %% [markdown]
# <h2 style="text-align: start; color: SteelBlue; text-transform: uppercase;">
#   Train-Test Split
# </h2>

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# <h4 style="text-align: start; color:red; text-transform: uppercase;">
# drop
# </h4>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40100 entries, 0 to 40099
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           40100 non-null  object
#  1   Delivery_person_ID           40100 non-null  object
#  2   Delivery_person_Age          40100 non-null  int64
#  3   Delivery_person_Ratings      40100 non-null  float64
#  4   Restaurant_latitude          40100 non-null  float64
#  5   Restaurant_longitude         40100 non-null  float64
#  6   Delivery_location_latitude   40100 non-null  float64
#  7   Delivery_location_longitude  40100 non-null  float64
#  8   Order_Date                   40100 non-null  datetime64[ns]
#  9   Time_Ordered                 40100 non-null  datetime64[ns]
#  10  Time_Order_picked            40100 non-null  datetime64[ns]
#  11  Weather_conditions           40100 non-null  object
#  12  Road_traffic_density         40100 non-null  object
#  13  Vehicle_condition            40100 non-null  int64
#  14  Type_of_order                40100 non-null  object
#  15  Type_of_vehicle              40100 non-null  object
#  16  Multiple_deliveries          39254 non-null  float64
#  17  Festival                     39896 non-null  object
#  18  City                         39050 non-null  object
#  19  Delivery_time                40100 non-null  int64
#  20  Distance                     40100 non-null  float64
#  21  Time_slot                    40100 non-null  object
#  22  Prepration_minute            40100 non-null  int64
#  23  Is_Weekend                   40100 non-null  int64
#  24  Peak_hour                    40100 non-null  object
# dtypes: datetime64[ns](3), float64(7), int64(5), object(10)
# memory usage: 7.6+ MB

# %%
data['Type_of_vehicle'].value_counts()
# Out:
# Type_of_vehicle
# motorcycle          23524
# scooter             13386
# electric_scooter     3190
# Name: count, dtype: int64

# %% [raw]
# ID
# - no relationship with delivery time.
#
# Delivery_person_ID
# - huge number of unique values
# - overfitting risk
#
# Restaurant_latitude
# Restaurant_longitude
# Delivery_location_latitude
# Delivery_location_longitude
# - These raw coordinates are difficult for models to understand directly.
# - so new feature created "Distance" it's summarizes how far delivery traveled.
#
# Order_Date
# - its optional but we created weekend featurs
# - so we created "Weekend"
#
# Time_Ordered
# Time_Order_picked
#
# - new feature created "prepration_minute","time_slot","peak_hour",
#
# Type_of_order
# -If the delivery time for a "Snack" is identical to a "Meal" across thousands of rows,
# -the feature has low variance and won't help the model distinguish between fast and slow deliveries.
#
# Vehicle_condition
# -The values 1, 0, and 2 are almost perfectly balanced in your dataset, which makes Vehicle_condition a strong candidate for dropping.

# %%
X = data.drop(
    columns = ["ID","Delivery_person_ID","Restaurant_latitude","Restaurant_longitude","Delivery_location_latitude","Delivery_location_longitude",
               "Order_Date","Time_Ordered","Time_Order_picked","Delivery_time","Type_of_order","Vehicle_condition"
    ],
    axis = 1
)
Y = data['Delivery_time']

# %%
X.columns
# Out:
# Index(['Delivery_person_Age', 'Delivery_person_Ratings', 'Weather_conditions',
#        'Road_traffic_density', 'Type_of_vehicle', 'Multiple_deliveries',
#        'Festival', 'City', 'Distance', 'Time_slot', 'Prepration_minute',
#        'Is_Weekend', 'Peak_hour'],
#       dtype='object')

# %%
Y.head(1)
# Out:
# 0    46
# Name: Delivery_time, dtype: int64

# %%
x_train,x_test,y_train,y_test = train_test_split(X,Y,random_state = 42 , test_size = 0.2)

# %%
x_train.shape,y_train.shape
# Out:
# ((32080, 13), (32080,))

# %%
x_test.shape,y_test.shape
# Out:
# ((8020, 13), (8020,))

# %% [markdown]
# <h2 style="text-align: start; color: SteelBlue; text-transform: uppercase;">
#   Missing Value Handling
# </h2>

# %%
from sklearn.impute import KNNImputer
from sklearn.impute import SimpleImputer

# %%
x_train.isna().sum()
# Out:
# Delivery_person_Age          0
# Delivery_person_Ratings      0
# Weather_conditions           0
# Road_traffic_density         0
# Type_of_vehicle              0
# Multiple_deliveries        664
# Festival                   156
# City                       832
# Distance                     0
# Time_slot                    0
# Prepration_minute            0
# Is_Weekend                   0
# Peak_hour                    0
# dtype: int64

# %%
 x_test.isna().sum()
# Out:
# Delivery_person_Age          0
# Delivery_person_Ratings      0
# Weather_conditions           0
# Road_traffic_density         0
# Type_of_vehicle              0
# Multiple_deliveries        182
# Festival                    48
# City                       218
# Distance                     0
# Time_slot                    0
# Prepration_minute            0
# Is_Weekend                   0
# Peak_hour                    0
# dtype: int64

# %%
y_train.isna().sum()
# Out:
# np.int64(0)

# %%
y_test.isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# <h4 style="text-align: start; color:red; text-transform: uppercase;">
# Multiple_deliveries
# </h4>

# %%
data['Multiple_deliveries'].unique()
# Out:
# array([ 3.,  1.,  0., nan,  2.])

# %%
imputer = KNNImputer(n_neighbors=5)

# %%
x_train['Multiple_deliveries'] = imputer.fit_transform(x_train[['Multiple_deliveries']]).astype(int)

# %%
x_test['Multiple_deliveries'] = imputer.transform(x_test[['Multiple_deliveries']]).astype(int)

# %% [markdown]
# <h4 style="text-align: start; color:red; text-transform: uppercase;">
# Festival and City
# </h4>

# %%
data['Festival'].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
data['City'].unique()
# Out:
# array(['Metropolitan', 'Urban', nan, 'Semi-Urban'], dtype=object)

# %%
cat_cols = ['Festival','City']

# %%
imp_mod = SimpleImputer(missing_values=np.nan, strategy='most_frequent')

# %%
x_train[cat_cols] = imp_mod.fit_transform(x_train[cat_cols])

# %%
x_test[cat_cols] = imp_mod.transform(x_test[cat_cols])

# %%
x_train.isna().sum()
# Out:
# Delivery_person_Age        0
# Delivery_person_Ratings    0
# Weather_conditions         0
# Road_traffic_density       0
# Type_of_vehicle            0
# Multiple_deliveries        0
# Festival                   0
# City                       0
# Distance                   0
# Time_slot                  0
# Prepration_minute          0
# Is_Weekend                 0
# Peak_hour                  0
# dtype: int64

# %%
x_test.isna().sum()
# Out:
# Delivery_person_Age        0
# Delivery_person_Ratings    0
# Weather_conditions         0
# Road_traffic_density       0
# Type_of_vehicle            0
# Multiple_deliveries        0
# Festival                   0
# City                       0
# Distance                   0
# Time_slot                  0
# Prepration_minute          0
# Is_Weekend                 0
# Peak_hour                  0
# dtype: int64

# %% [markdown]
# <h2 style="text-align: start; color: SteelBlue; text-transform: uppercase;">
#   Outlier Handling
# </h2>

# %%
num_colms =  x_train.select_dtypes(exclude='object').columns
num_colms
# Out:
# Index(['Delivery_person_Age', 'Delivery_person_Ratings', 'Multiple_deliveries',
#        'Distance', 'Prepration_minute', 'Is_Weekend'],
#       dtype='object')

# %%
for col in x_train.select_dtypes(exclude='object').columns:
    plt.figure(figsize=(12, 6))
    plt.title(f"--------{col}--------")
    sns.boxplot(x=data[col],fill=False)
    plt.show()

# %% [raw]
# Based on this report dont need remove outliers or handle because tha way real life works same.

# %%
for col in x_test.select_dtypes(exclude='object').columns:
    plt.figure(figsize=(12, 6))
    plt.title(f"--------{col}--------")
    sns.boxplot(x=data[col],fill=False)
    plt.show()

# %% [raw]
# Based on this report dont need remove outliers or handle because tha way real life works same.

# %% [markdown]
# <h2 style="text-align: start; color: SteelBlue; text-transform: uppercase;">
#   Encoding
# </h2>

# %%
from sklearn.preprocessing import OneHotEncoder,OrdinalEncoder

# %%
oh_encoder = OneHotEncoder(
    drop='first',
    sparse_output=False,
    handle_unknown='ignore'
)

# %%
for col in x_train.select_dtypes(include='object'):
    print(f"-----------{col}----------")
    print(x_train[col].unique())
# Out:
# -----------Weather_conditions----------
# ['Sandstorms' 'Stormy' 'Fog' 'Windy' 'Cloudy' 'Sunny']
# -----------Road_traffic_density----------
# ['Medium' 'Low' 'Jam' 'High']
# -----------Type_of_vehicle----------
# ['scooter' 'motorcycle' 'electric_scooter']
# -----------Festival----------
# ['No' 'Yes']
# -----------City----------
# ['Metropolitan' 'Urban' 'Semi-Urban']
# -----------Time_slot----------
# ['Evening' 'Morning' 'Night' 'Afternoon']
# -----------Peak_hour----------
# ['Non-Peak Hour' 'Peak Hour']

# %% [markdown]
# <h4 style="text-align: start; color:red; text-transform: uppercase;">
# Festival
# </h4>

# %%
x_train['Festival'] = x_train['Festival'].map(
    {
        'Yes':1,
        'No':0
    }
)
x_test['Festival'] = x_test['Festival'].map(
    {
        'Yes':1,
        'No':0
    }
)

# %% [markdown]
# <h4 style="text-align: start; color:red; text-transform: uppercase;">
# Peak_hour
# </h4>

# %%
x_train['Peak_hour'] = x_train['Peak_hour'].map(
    {
        'Peak Hour':1,
        'Non-Peak Hour':0
    }
)
x_test['Peak_hour'] = x_test['Peak_hour'].map(
    {
        'Peak Hour':1,
        'Non-Peak Hour':0
    }
)

# %% [markdown]
# <h4 style="text-align: start; color:red; text-transform: uppercase;">
# Weather_conditions
# </h4>

# %%
x_train = pd.concat(
    [
        x_train.drop(columns=['Weather_conditions'],axis=1),
        pd.DataFrame(
            data = oh_encoder.fit_transform(x_train[['Weather_conditions']]).astype(int),
            columns = oh_encoder.get_feature_names_out(['Weather_conditions']),
            index = x_train.index
        )
    ],
    axis=1
)
x_test = pd.concat(
    [
        x_test.drop(columns=['Weather_conditions'],axis=1),
        pd.DataFrame(
            data = oh_encoder.transform(x_test[['Weather_conditions']]).astype(int),
            columns = oh_encoder.get_feature_names_out(['Weather_conditions']),
            index = x_test.index
        )
    ],
    axis=1
)

# %% [markdown]
# <h4 style="text-align: start; color:red; text-transform: uppercase;">
# Road_traffic_density
# </h4>

# %%
traffic_order = OrdinalEncoder(
    categories=[['Low','Medium','High','Jam']],
    unknown_value=-1,
    handle_unknown='use_encoded_value'
)

x_train['Road_traffic_density'] = traffic_order.fit_transform(x_train[['Road_traffic_density']]).astype(int)
x_test['Road_traffic_density'] = traffic_order.transform(x_test[['Road_traffic_density']]).astype(int)

# %% [markdown]
# <h4 style="text-align: start; color:red; text-transform: uppercase;">
# Type_of_vehicle
# </h4>

# %%
x_train = pd.concat(
    [
        x_train.drop(columns=['Type_of_vehicle'],axis=1),
        pd.DataFrame(
            data = oh_encoder.fit_transform(x_train[['Type_of_vehicle']]).astype(int),
            columns = oh_encoder.get_feature_names_out(['Type_of_vehicle']),
            index = x_train.index
        )
    ],axis=1
)
x_test = pd.concat(
    [
        x_test.drop(columns=['Type_of_vehicle'],axis=1),
        pd.DataFrame(
            data = oh_encoder.transform(x_test[['Type_of_vehicle']]).astype(int),
            columns = oh_encoder.get_feature_names_out(['Type_of_vehicle']),
            index = x_test.index
        )
    ],axis=1
)

# %% [markdown]
# <h4 style="text-align: start; color:red; text-transform: uppercase;">
# City
# </h4>

# %%
city_order = OrdinalEncoder(
    categories=[['Semi-Urban','Urban','Metropolitan']],
    handle_unknown='use_encoded_value',
    unknown_value=-1
)
x_train['City'] = city_order.fit_transform(x_train[['City']]).astype(int)
x_test['City'] = city_order.transform(x_test[['City']]).astype(int)

# %% [markdown]
# <h4 style="text-align: start; color:red; text-transform: uppercase;">
# Time_slot
# </h4>

# %%
time_order = OrdinalEncoder(
    categories=[[ 'Morning','Afternoon','Evening','Night' ]],
    handle_unknown='use_encoded_value',
    unknown_value=-1
)
x_train['Time_slot'] = time_order.fit_transform(x_train[['Time_slot']]).astype(int)
x_test['Time_slot'] = time_order.transform(x_test[['Time_slot']]).astype(int)

# %%
for col in x_test:
    print(f"-----------{col}----------")
    print(x_train[col].unique())
# Out:
# -----------Delivery_person_Age----------
# [39 27 28 26 32 37 21 25 29 23 36 24 20 35 22 33 38 30 34 31]
# -----------Delivery_person_Ratings----------
# [4.7 4.1 4.5 4.8 3.9 4.6 4.9 5.  4.2 4.3 3.5 2.6 4.4 4.  3.8 3.7 2.7 3.6
#  3.2 2.5 3.4 3.1 3.3 2.8 2.9 3. ]
# -----------Road_traffic_density----------
# [1 0 3 2]
# -----------Multiple_deliveries----------
# [1 0 2 3]
# -----------Festival----------
# [0 1]
# -----------City----------
# [2 1 0]
# -----------Distance----------
# [7.6497244  9.32682954 1.51257469 ... 7.54997184 6.05407028 2.9304183 ]
# -----------Time_slot----------
# [2 0 3 1]
# -----------Prepration_minute----------
# [ 5 15 10]
# -----------Is_Weekend----------
# [0 1]
# -----------Peak_hour----------
# [0 1]
# -----------Weather_conditions_Fog----------
# [0 1]
# -----------Weather_conditions_Sandstorms----------
# [1 0]
# -----------Weather_conditions_Stormy----------
# [0 1]
# -----------Weather_conditions_Sunny----------
# [0 1]
# -----------Weather_conditions_Windy----------
# [0 1]
# -----------Type_of_vehicle_motorcycle----------
# [0 1]
# -----------Type_of_vehicle_scooter----------
# [1 0]

# %% [markdown]
# <h2 style="text-align: start; color: SteelBlue; text-transform: uppercase;">
#   Scaling
# </h2>

# %%
from sklearn.preprocessing  import StandardScaler
ss_scalor = StandardScaler()

# %%
x_test.head(2)
# Out:
#        Delivery_person_Age  Delivery_person_Ratings  Road_traffic_density  \
# 7653                    27                      4.8                     3
# 34523                   30                      4.6                     1
#
#        Multiple_deliveries  Festival  City   Distance  Time_slot  \
# 7653                     1         0     2  13.681492          2
# 34523                    0         0     2  13.613850          2
#
#        Prepration_minute  Is_Weekend  Peak_hour  Weather_conditions_Fog  \
# 7653                  10           0          1                       0
# 34523                 10           1          1                       0
#
#        Weather_conditions_Sandstorms  Weather_conditions_Stormy  \
# 7653                               0                          0
# 34523                              0                          0
#
#        Weather_conditions_Sunny  Weather_conditions_Windy  \
# 7653                          0                         1
# 34523                         1                         0
#
#        Type_of_vehicle_motorcycle  Type_of_vehicle_scooter
# 7653                            1                        0
# 34523                           1                        0

# %%
x_test.head(2)
# Out:
#        Delivery_person_Age  Delivery_person_Ratings  Road_traffic_density  \
# 7653                    27                      4.8                     3
# 34523                   30                      4.6                     1
#
#        Multiple_deliveries  Festival  City   Distance  Time_slot  \
# 7653                     1         0     2  13.681492          2
# 34523                    0         0     2  13.613850          2
#
#        Prepration_minute  Is_Weekend  Peak_hour  Weather_conditions_Fog  \
# 7653                  10           0          1                       0
# 34523                 10           1          1                       0
#
#        Weather_conditions_Sandstorms  Weather_conditions_Stormy  \
# 7653                               0                          0
# 34523                              0                          0
#
#        Weather_conditions_Sunny  Weather_conditions_Windy  \
# 7653                          0                         1
# 34523                         1                         0
#
#        Type_of_vehicle_motorcycle  Type_of_vehicle_scooter
# 7653                            1                        0
# 34523                           1                        0

# %%
x_train.shape
# Out:
# (32080, 18)

# %%
scale_cols = [
    'Delivery_person_Age',
    'Delivery_person_Ratings',
    'Distance',
]
x_train[scale_cols] = ss_scalor.fit_transform(x_train[scale_cols])
x_test[scale_cols] = ss_scalor.transform(x_test[scale_cols])

# %%
x_test.head(2)
# Out:
#        Delivery_person_Age  Delivery_person_Ratings  Road_traffic_density  \
# 7653             -0.444671                 0.524904                     3
# 34523             0.076249                -0.107734                     1
#
#        Multiple_deliveries  Festival  City  Distance  Time_slot  \
# 7653                     1         0     2  0.711472          2
# 34523                    0         0     2  0.699384          2
#
#        Prepration_minute  Is_Weekend  Peak_hour  Weather_conditions_Fog  \
# 7653                  10           0          1                       0
# 34523                 10           1          1                       0
#
#        Weather_conditions_Sandstorms  Weather_conditions_Stormy  \
# 7653                               0                          0
# 34523                              0                          0
#
#        Weather_conditions_Sunny  Weather_conditions_Windy  \
# 7653                          0                         1
# 34523                         1                         0
#
#        Type_of_vehicle_motorcycle  Type_of_vehicle_scooter
# 7653                            1                        0
# 34523                           1                        0

# %%
x_test.head(2)
# Out:
#        Delivery_person_Age  Delivery_person_Ratings  Road_traffic_density  \
# 7653             -0.444671                 0.524904                     3
# 34523             0.076249                -0.107734                     1
#
#        Multiple_deliveries  Festival  City  Distance  Time_slot  \
# 7653                     1         0     2  0.711472          2
# 34523                    0         0     2  0.699384          2
#
#        Prepration_minute  Is_Weekend  Peak_hour  Weather_conditions_Fog  \
# 7653                  10           0          1                       0
# 34523                 10           1          1                       0
#
#        Weather_conditions_Sandstorms  Weather_conditions_Stormy  \
# 7653                               0                          0
# 34523                              0                          0
#
#        Weather_conditions_Sunny  Weather_conditions_Windy  \
# 7653                          0                         1
# 34523                         1                         0
#
#        Type_of_vehicle_motorcycle  Type_of_vehicle_scooter
# 7653                            1                        0
# 34523                           1                        0

# %% [markdown]
# <h2 style="text-align: start; color: SteelBlue; text-transform: uppercase;">
#  Model Building
# </h2>

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor

# %% [markdown]
# <h4 style="text-align: start; color:red; text-transform: uppercase;">
# LinearRegression
# </h4>

# %%
lr_model = LinearRegression()
lr_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# <h4 style="text-align: start; color:red; text-transform: uppercase;">
# RandomForestRegressor
# </h4>

# %%
rfr_model = RandomForestRegressor()
rfr_model.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %% [markdown]
# <h4 style="text-align: start; color:red; text-transform: uppercase;">
# XGBRegressor
# </h4>

# %%
xgb_model = XGBRegressor()
xgb_model.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...)

# %% [markdown]
# <h4 style="text-align: start; color:red; text-transform: uppercase;">
# KNeighborsRegressor
# </h4>

# %%
knr_model = KNeighborsRegressor()
knr_model.fit(x_train,y_train)
# Out:
# KNeighborsRegressor()

# %% [markdown]
# <h4 style="text-align: start; color:red; text-transform: uppercase;">
# SVM Regressor (SVR)
# </h4>

# %%
svr_model = SVR()
svr_model.fit(x_train,y_train)
# Out:
# SVR()

# %% [markdown]
# <h4 style="text-align: start; color:red; text-transform: uppercase;">
# DecisionTreeRegressor
# </h4>

# %%
dtr_model = DecisionTreeRegressor()
dtr_model.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %% [markdown]
# <h2 style="text-align: start; color: SteelBlue; text-transform: uppercase;">
# Model Evaluation
# </h2>

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

# %%
results = []

def evaluate_model(model,x_train,x_test,y_train,y_test,name):
    
    model.fit(x_train,y_train)
    
    y_train_pred = model.predict(x_train)
    y_test_pred  = model.predict(x_test)

    return{
        "Model":name,
        
        "Train R2":r2_score(y_train,y_train_pred),
        "Test R2": r2_score(y_test,y_test_pred),

        "Train MSE":mean_squared_error(y_train,y_train_pred),
        "Test MSE" : mean_squared_error(y_test,y_test_pred),

        "Train MAE":mean_absolute_error(y_train,y_train_pred),
        "Test MAE": mean_absolute_error(y_test,y_test_pred),

        "Train RMSE":np.sqrt(mean_squared_error(y_train,y_train_pred)),
        "Test RMSE": np.sqrt(mean_squared_error(y_test,y_test_pred))       
        
    }

# %%
results.append(evaluate_model(lr_model,x_train,x_test,y_train,y_test,"LinearRegression"))
results.append(evaluate_model(rfr_model,x_train,x_test,y_train,y_test,"RandomForestRegressor"))
results.append(evaluate_model(xgb_model,x_train,x_test,y_train,y_test,"XGBRegressor "))
results.append(evaluate_model(knr_model,x_train,x_test,y_train,y_test,"KNeighborsRegressor"))
results.append(evaluate_model(svr_model,x_train,x_test,y_train,y_test,"SVM Regressor (SVR) "))
results.append(evaluate_model(dtr_model,x_train,x_test,y_train,y_test,"DecisionTreeRegressor"))

# %%
reslt_table  = pd.DataFrame(results)
reslt_table
# Out:
#                    Model  Train R2   Test R2  Train MSE   Test MSE  Train MAE  \
# 0       LinearRegression  0.567223  0.558731  38.097224  38.390390   4.901922
# 1  RandomForestRegressor  0.967806  0.764872   2.834027  20.456148   1.309125
# 2          XGBRegressor   0.834174  0.777271  14.597610  19.377428   3.012663
# 3    KNeighborsRegressor  0.776594  0.649582  19.666332  30.486344   3.424701
# 4   SVM Regressor (SVR)   0.587411  0.582839  36.320066  36.292997   4.740586
# 5  DecisionTreeRegressor  0.999999  0.573228   0.000078  37.129177   0.000094
#
#    Test MAE  Train RMSE  Test RMSE
# 0  4.913358    6.172295   6.195998
# 1  3.538618    1.683457   4.522847
# 2  3.479212    3.820682   4.401980
# 3  4.266334    4.434674   5.521444
# 4  4.743137    6.026613   6.024367
# 5  4.623192    0.008828   6.093372

# %% [raw]
# Among all regression models, XGBoost Regressor achieved the best overall performance with strong generalization and balanced train-test scores. Random Forest showed higher overfitting, while Decision Tree severely overfit the training data. Linear Regression and SVR underperformed due to the nonlinear nature of delivery time prediction.

# %% [raw]
# Random Forest showed the highest predictive accuracy in this split.
# XGBoost demonstrated better generalization capability and model stability.
# Decision Tree severely overfitted the training data.
# Linear Regression underperformed due to the non-linear nature of the problem.
# KNN and SVR produced moderate performance compared to ensemble models.

# %% [markdown]
# <h2 style="text-align: start; color: SteelBlue; text-transform: uppercase;">
# Hyperparameter Tuning
# </h2>

# %%
from sklearn.model_selection import RandomizedSearchCV

# %% [markdown]
# <h4 style="text-align: start; color:red; text-transform: uppercase;">
# XGBRegressor
# </h4>

# %%
xgb_model = XGBRegressor(random_state=42)

# %%
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [4,5,6],
    'learning_rate': [0.01, 0.05, 0.1],
    'subsample': [0.7, 0.8],
    'colsample_bytree': [0.7, 0.8, 1.0],
    'reg_alpha': [0, 0.1, 1],
    'reg_lambda': [1, 2, 5],
    'gamma': [0, 0.1, 0.3]
}

# %%
random_search_xgb = RandomizedSearchCV(
    estimator = xgb_model,
    param_distributions = param_grid,
    scoring='neg_root_mean_squared_error',
    n_iter=20,
    cv=5,
    verbose=2,
    random_state=42,
    n_jobs=-1
)
random_search_xgb.fit(x_train, y_train, eval_set=[(x_test, y_test)],verbose=False)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# RandomizedSearchCV(cv=5,
#                    estimator=XGBRegressor(base_score=None, booster=None,
#                                           callbacks=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=None, device=None,
#                                           early_stopping_rounds=None,
#                                           enable_categorical=False,
#                                           eval_metric=None, feature_types=None,
#                                           feature_weights=None, gamma=None,
#                                           grow_policy=None,
#                                           importance_type=None,
#                                           interaction_constraint...
#                                           n_estimators=None, n_jobs=None,
#                                           num_parallel_tree=None, ...),
#                    n_iter=20, n_jobs=-1,
#                    param_distributions={'colsample_bytree': [0.7, 0.8, 1.0],
#                                         'gamma': [0, 0.1, 0.3],
#                                         'learning_rate': [0.01, 0.05, 0.1],
#                                         'max_depth': [4, 5, 6],
#                                         'n_estimators': [100, 200, 300],
#                                         'reg_alpha': [0, 0.1, 1],
#                                         'reg_lambda': [1, 2, 5],
#                                         'subsample': [0.7, 0.8]},
#                    random_state=42, scoring='neg_root_mean_squared_error',
#                    verbose=2)

# %%
random_search_xgb.best_params_
# Out:
# {'subsample': 0.7,
#  'reg_lambda': 5,
#  'reg_alpha': 1,
#  'n_estimators': 200,
#  'max_depth': 6,
#  'learning_rate': 0.1,
#  'gamma': 0,
#  'colsample_bytree': 0.7}

# %%
best_xgb = random_search_xgb.best_estimator_

# %%
y_train_pred = best_xgb.predict(x_train)
y_test_pred = best_xgb.predict(x_test)

# %%
new_result = []
new_result.append(evaluate_model(best_xgb,x_train,x_test,y_train,y_test,"Tuned XGBoost"))

# %%
new_result_table = pd.DataFrame(new_result)
new_result_table
# Out:
#            Model  Train R2   Test R2  Train MSE   Test MSE  Train MAE  \
# 0  Tuned XGBoost  0.813718  0.779005  16.398327  19.226597   3.203966
#
#    Test MAE  Train RMSE  Test RMSE
# 0  3.467858    4.049485   4.384814

# %% [markdown]
# <h4 style="text-align: start; color:red; text-transform: uppercase;">
# RandomForestRegressor
# </h4>

# %%
rf_model = RandomForestRegressor(
    random_state=42
)

# %%
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [5, 10, 15],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [2, 4, 6],
    'max_features': ['sqrt'],
    'bootstrap': [True]
}

# %%
random_search_rf = RandomizedSearchCV(
    estimator=rf_model,
    param_distributions=param_grid,
    n_iter=20,
    scoring='neg_root_mean_squared_error',
    cv=5,
    verbose=2,
    random_state=42,
    n_jobs=-1
)
random_search_rf.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(random_state=42),
#                    n_iter=20, n_jobs=-1,
#                    param_distributions={'bootstrap': [True],
#                                         'max_depth': [5, 10, 15],
#                                         'max_features': ['sqrt'],
#                                         'min_samples_leaf': [2, 4, 6],
#                                         'min_samples_split': [2, 5, 10],
#                                         'n_estimators': [100, 200]},
#                    random_state=42, scoring='neg_root_mean_squared_error',
#                    verbose=2)

# %%
random_search_rf.best_params_
# Out:
# {'n_estimators': 200,
#  'min_samples_split': 2,
#  'min_samples_leaf': 2,
#  'max_features': 'sqrt',
#  'max_depth': 15,
#  'bootstrap': True}

# %%
best_rf = random_search_rf.best_estimator_

# %%
new_result.append(evaluate_model(best_rf,x_train,x_test,y_train,y_test,"Tuned Random Forest"))

# %%
new_result_table = pd.DataFrame(new_result)
new_result_table
# Out:
#                  Model  Train R2   Test R2  Train MSE   Test MSE  Train MAE  \
# 0        Tuned XGBoost  0.813718  0.779005  16.398327  19.226597   3.203966
# 1  Tuned Random Forest  0.841761  0.770653  13.929712  19.953141   2.895313
#
#    Test MAE  Train RMSE  Test RMSE
# 0  3.467858    4.049485   4.384814
# 1  3.505774    3.732253   4.466894

# %% [raw]
# After hyperparameter tuning, both Random Forest and XGBoost showed reduced overfitting and improved generalization. Tuned XGBoost achieved the best overall performance with higher Test R² and lower prediction errors compared to Tuned Random Forest.

# %% [markdown]
# <h2 style="text-align: start; color: SteelBlue; text-transform: uppercase;">
#  Feature Importance / Model Interpretation
# </h2>

# %% [raw]
# Feature Importance / Model Interpretation was performed to identify the most influential features affecting delivery time prediction and to understand how the model makes predictions.

# %%
importance_1 = best_xgb.feature_importances_

feature_importance_1 = pd.DataFrame({
    'Feature': x_train.columns,
    'Importance': importance_1
}).sort_values(by='Importance', ascending=False)

feature_importance_1
# Out:
#                           Feature  Importance
# 14       Weather_conditions_Sunny    0.142348
# 3             Multiple_deliveries    0.106973
# 2            Road_traffic_density    0.105676
# 11         Weather_conditions_Fog    0.097434
# 10                      Peak_hour    0.095190
# 4                        Festival    0.091721
# 1         Delivery_person_Ratings    0.084821
# 0             Delivery_person_Age    0.040577
# 15       Weather_conditions_Windy    0.038700
# 12  Weather_conditions_Sandstorms    0.035442
# 13      Weather_conditions_Stormy    0.034748
# 16     Type_of_vehicle_motorcycle    0.031131
# 7                       Time_slot    0.030528
# 6                        Distance    0.028480
# 5                            City    0.019073
# 17        Type_of_vehicle_scooter    0.011379
# 8               Prepration_minute    0.003028
# 9                      Is_Weekend    0.002750

# %%
importance_2 = best_rf.feature_importances_

feature_importance_2 = pd.DataFrame({
    'Feature': x_train.columns,
    'Importance': importance_2
}).sort_values(by='Importance', ascending=False)

feature_importance_2
# Out:
#                           Feature  Importance
# 1         Delivery_person_Ratings    0.193699
# 0             Delivery_person_Age    0.127989
# 6                        Distance    0.123185
# 2            Road_traffic_density    0.119119
# 3             Multiple_deliveries    0.106198
# 14       Weather_conditions_Sunny    0.071883
# 10                      Peak_hour    0.055210
# 4                        Festival    0.039407
# 11         Weather_conditions_Fog    0.032903
# 16     Type_of_vehicle_motorcycle    0.020945
# 7                       Time_slot    0.020907
# 13      Weather_conditions_Stormy    0.018155
# 15       Weather_conditions_Windy    0.016886
# 12  Weather_conditions_Sandstorms    0.016548
# 5                            City    0.015080
# 17        Type_of_vehicle_scooter    0.009856
# 8               Prepration_minute    0.007920
# 9                      Is_Weekend    0.004109

# %% [raw]
# Environmental and operational factors (traffic, weather, peak hours, and festival conditions) have a stronger impact on delivery time than personal or demographic factors. Distance contributes moderately but is not the dominant predictor.

# %% [raw]
# XGBoost and Random Forest show different importance distributions, but both confirm that delivery conditions and demand-related factors are more influential than static attributes like age or vehicle type.

# %% [raw]
# Feature importance analysis from XGBoost and Random Forest shows that delivery time is primarily influenced by environmental and operational factors such as traffic density, weather conditions, peak hours, and multiple deliveries. In contrast, distance plays a secondary role, likely due to interaction with traffic and urban delivery conditions.

# %% [markdown]
# <h2 style="text-align: start; color: SteelBlue; text-transform: uppercase;">
# Final Insights & Business Conclusion
# </h2>

# %% [markdown]
# <h3 style="text-align: start; color:red; text-transform: uppercase;">
#     Key findings
# </h3>

# %% [raw]
# - Delivery time is mainly affected by traffic, weather, and peak hours
# - Distance has moderate influence, not dominant
# - Operational conditions matter more than personal attributes
# - XGBoost performed best with balanced accuracy and generalization

# %% [markdown]
# <h3 style="text-align: start; color:red; text-transform: uppercase;">
#     Business insight
# </h3>

# %% [raw]
# - Delivery delays are not mainly caused by distance, but by traffic congestion and time of order
#   Peak hours and festivals significantly increase delivery time
# - Optimizing routing alone is not enough; scheduling matters more

# %% [markdown]
# <h3 style="text-align: start; color:red; text-transform: uppercase;">
#     Recommendations
# </h3>

# %% [raw]
# - Optimize delivery allocation during peak hours
# - Assign more delivery agents during high traffic periods
# - Use real-time traffic data for routing decisions
# - Prioritize urgent orders outside festival/peak times

# %% [markdown]
# <h3 style="text-align: start; color:red; text-transform: uppercase;">
#     Final model selection
# </h3>

# %% [raw]
# - Best model =  XGBoost
# - Reason =  best balance of accuracy and generalization
# - Final R² ~ 0.78–0.83 range is realistic for this problem

# %% [markdown]
# <h2 style="text-align: start; color: SteelBlue; text-transform: uppercase;">
# Deployment
# </h2>

# %%
import pickle

# %%
# pickle.dump(best_xgb, open('model.pkl', 'wb'))
# pickle.dump(ss_scalor, open('scaler.pkl', 'wb'))

# %%
# feature_columns = x_train.columns
# pickle.dump(feature_columns, open('features.pkl', 'wb'))

# %%
sample = x_test.iloc[2:3].copy()
sample
# Out:
#        Delivery_person_Age  Delivery_person_Ratings  Road_traffic_density  \
# 11543            -1.312871                 0.208585                     3
#
#        Multiple_deliveries  Festival  City  Distance  Time_slot  \
# 11543                    1         0     2  0.711571          3
#
#        Prepration_minute  Is_Weekend  Peak_hour  Weather_conditions_Fog  \
# 11543                 10           0          1                       0
#
#        Weather_conditions_Sandstorms  Weather_conditions_Stormy  \
# 11543                              1                          0
#
#        Weather_conditions_Sunny  Weather_conditions_Windy  \
# 11543                         0                         0
#
#        Type_of_vehicle_motorcycle  Type_of_vehicle_scooter
# 11543                           0                        1

# %%
sample_1 = y_test.iloc[2:3].copy()
sample_1
# Out:
# 11543    19
# Name: Delivery_time, dtype: int64

# %%
sample = x_test.iloc[2:3].copy()
sample_scaled = sample.copy()
# sample_scaled[['Delivery_person_Age','Delivery_person_Ratings','Distance']] = ss_scalor.transform(
#     sample_scaled[['Delivery_person_Age','Delivery_person_Ratings','Distance']]
# )

# %%
print(random_search_xgb.predict(sample_scaled).round())
# Out:
# [22.]
